# %% [markdown]
# <h3>Import packages</h3>

# %%
from datetime import date
from timeit import default_timer as timer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
# from keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import imagenet_utils
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Configure TensorFlow to use GPU for training
tf.config.list_physical_devices('GPU') 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_physical_devices('GPU')
#Set GPU memory limit so my GPU doesn't crash
if gpus:
    try:
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <h3>Create class to record time taken to train the model</h3>

# %%
#class to record time taken to train per epoch
class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

# %% [markdown]
# <h3>Create train and test folder</h3>

# %%
#creates a folder each time the set of code is run to sort dataset into train and test
day = date.today()
formatDate = day.strftime("%b-%d-%Y")

#create folder with current date to group predictions ran in a day together, if it does not exists
if os.path.isdir('Prediction (' + formatDate + ')') is False:
    folder = os.mkdir('Prediction (' + formatDate + ')')
folder = 'Prediction (' + formatDate + ')'

#looping through to find if destination folder exists
i = 1
while True:
    if os.path.isdir(folder + '/dataset_6 - ' + str(i)) is False:
        break
    i += 1

#destination path for unsorted folder
destination = folder + '/dataset_6 - ' + str(i)

#source path for unsorted folder
source = 'dataset_6/'

#duplicate the unsorted folder from source to destination
shutil.copytree(source, destination)

os.mkdir(destination + '/train')
os.mkdir(destination + '/test')

# %% [markdown]
# <h3>Sort dataset into train and test folder</h3>

# %%
#function to split images into training (80%) and testing (20%) and return both
def split(data):
    num = int(len(data) * 0.8)
    # num = int(len(data) * 0.9) #90/10 split
#     num = int(len(data) * 0.7) #70/30 split
    random.shuffle(data)
    return data[:num], data[num:]

dir = os.chdir(destination)
for category in os.listdir(dir):
    #skip the iteration if folder is "train" or "test"
    skip = ['train', 'test']
    if category in skip:
        continue
    
    shutil.move(f'{category}', 'train')
    #create a subfolder with the same name in test
    os.mkdir(f'test/{category}')

    #get the images in each folder (xray type) for spltting of data into training and testing
    img = os.listdir(f'train/{category}')
    training, testing = split(img)
    
    for file in testing:
        shutil.move(f'train/{category}/{file}', f'test/{category}')

# %% [markdown]
# <h3>Transfer Learning</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.MobileNet(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %%
mobile.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
# =================================================================
# Total params: 3,228,864
# Trainable params: 3,206,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
for layer in mobile.layers[:-2]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))
x = mobile(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(1, activation="sigmoid")(x)  

model = keras.Model(inputs, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 3,229,889
# Trainable params: 3,073
# Non-trainable params: 3,226,816
# _________________________________________________________________

# %% [markdown]
# <h3>Process data</h3>

# %%
train_path = 'train'
test_path = 'test'

#for data augmentation on training data
datagen = ImageDataGenerator( 
    preprocessing_function =tf.keras.applications.resnet50.preprocess_input,
    validation_split=0.2,
    # validation_split=0.1, #changes made for 90/10 split
    rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.2, # Randomly zoom image 
    width_shift_range = 0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range = 0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip = True,  # randomly flip images
#     vertical_flip = False,    # randomly flip images
    vertical_flip = True, #include vertical flip for better generalisation
    )  

#takes images from directory path and generates batches of augmented data
train = datagen.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    class_mode = 'binary',
    batch_size=32,
    subset='training',
        shuffle = False)

#for validation data
validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input, 
                                        validation_split=0.2)
# validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
#                                         validation_split=0.1) #changes made for 90/10 split


validation = validation_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    class_mode = 'binary',
    batch_size=32,
    subset='validation',
        shuffle = False)

#for test data
test = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input)\
.flow_from_directory(directory=test_path, target_size=(224,224), class_mode = 'binary', batch_size=32, shuffle=False)
# Out:
# Found 276 images belonging to 2 classes.
# Found 68 images belonging to 2 classes.
# Found 86 images belonging to 2 classes.

# %% [markdown]
# <h3>Train model</h3>

# %%
model.compile(optimizer=Adam(learning_rate=0.0006), loss='binary_crossentropy', metrics=['binary_accuracy']) #Last best setting
# model.compile(optimizer=Adam(learning_rate=0.006), loss='binary_crossentropy', metrics=['accuracy']) #Last best setting
checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_binary_accuracy',
    # monitor='val_accuracy',
    mode='max',
    save_best_only=True) #save best model

#more epochs for better results
result = model.fit(x=train, validation_data=validation, epochs=150, verbose=2, callbacks=[model_checkpoint_callback,cb])
# Out:
# Epoch 1/150
# 9/9 - 13s - loss: 0.9973 - binary_accuracy: 0.5181 - val_loss: 0.6505 - val_binary_accuracy: 0.6471 - 13s/epoch - 1s/step
# Epoch 2/150
# 9/9 - 3s - loss: 0.8589 - binary_accuracy: 0.5399 - val_loss: 0.6493 - val_binary_accuracy: 0.6471 - 3s/epoch - 338ms/step
# Epoch 3/150
# 9/9 - 3s - loss: 0.8662 - binary_accuracy: 0.5580 - val_loss: 0.6527 - val_binary_accuracy: 0.6471 - 3s/epoch - 331ms/step
# Epoch 4/150
# 9/9 - 3s - loss: 0.8999 - binary_accuracy: 0.5725 - val_loss: 0.6376 - val_binary_accuracy: 0.6471 - 3s/epoch - 329ms/step
# Epoch 5/150
# 9/9 - 3s - loss: 0.8562 - binary_accuracy: 0.5399 - val_loss: 0.6059 - val_binary_accuracy: 0.7059 - 3s/epoch - 364ms/step
# Epoch 6/150
# 9/9 - 3s - loss: 0.8904 - binary_accuracy: 0.5109 - val_loss: 0.5940 - val_binary_accuracy: 0.6471 - 3s/epoch - 334ms/step
# Epoch 7/150
# 9/9 - 3s - loss: 0.8169 - binary_accuracy: 0.5725 - val_loss: 0.5969 - val_binary_accuracy: 0.7059 - 3s/epoch - 324ms/step
# Epoch 8/150
# 9/9 - 3s - loss: 0.8917 - binary_accuracy: 0.5362 - val_loss: 0.6099 - val_binary_accuracy: 0.6765 - 3s/epoch - 328ms/step
# Epoch 9/150
# 9/9 - 3s - loss: 0.7430 - binary_accuracy: 0.6232 - val_loss: 0.6044 - val_binary_accuracy: 0.6912 - 3s/epoch - 322ms/step
# Epoch 10/150
# 9/9 - 3s - loss: 0.7340 - binary_accuracy: 0.6667 - val_loss: 0.5817 - val_binary_accuracy: 0.7059 - 3s/epoch - 319ms/step
# Epoch 11/150
# 9/9 - 3s - loss: 0.8582 - binary_accuracy: 0.5761 - val_loss: 0.5600 - val_binary_accuracy: 0.7206 - 3s/epoch - 354ms/step
# Epoch 12/150
# 9/9 - 3s - loss: 0.8820 - binary_accuracy: 0.5688 - val_loss: 0.5630 - val_binary_accuracy: 0.7206 - 3s/epoch - 333ms/step
# Epoch 13/150
# 9/9 - 3s - loss: 0.7593 - binary_accuracy: 0.6051 - val_loss: 0.5622 - val_binary_accuracy: 0.7059 - 3s/epoch - 332ms/step
# Epoch 14/150
# 9/9 - 4s - loss: 0.8233 - binary_accuracy: 0.5797 - val_loss: 0.5613 - val_binary_accuracy: 0.7059 - 4s/epoch - 404ms/step
# Epoch 15/150
# 9/9 - 3s - loss: 0.7903 - binary_accuracy: 0.6159 - val_loss: 0.5421 - val_binary_accuracy: 0.7353 - 3s/epoch - 352ms/step
# Epoch 16/150
# 9/9 - 3s - loss: 0.7845 - binary_accuracy: 0.5942 - val_loss: 0.5491 - val_binary_accuracy: 0.7059 - 3s/epoch - 331ms/step
# Epoch 17/150
# 9/9 - 3s - loss: 0.8192 - binary_accuracy: 0.5906 - val_loss: 0.5375 - val_binary_accuracy: 0.7353 - 3s/epoch - 319ms/step
# Epoch 18/150
# 9/9 - 3s - loss: 0.7415 - binary_accuracy: 0.6268 - val_loss: 0.5266 - val_binary_accuracy: 0.7647 - 3s/epoch - 345ms/step
# Epoch 19/150
# 9/9 - 3s - loss: 0.7436 - binary_accuracy: 0.6087 - val_loss: 0.5447 - val_binary_accuracy: 0.7059 - 3s/epoch - 329ms/step
# Epoch 20/150
# 9/9 - 3s - loss: 0.8148 - binary_accuracy: 0.6014 - val_loss: 0.5357 - val_binary_accuracy: 0.7206 - 3s/epoch - 320ms/step
# Epoch 21/150
# 9/9 - 3s - loss: 0.8548 - binary_accuracy: 0.5326 - val_loss: 0.5268 - val_binary_accuracy: 0.7647 - 3s/epoch - 322ms/step
# Epoch 22/150
# 9/9 - 3s - loss: 0.7640 - binary_accuracy: 0.6232 - val_loss: 0.5302 - val_binary_accuracy: 0.7500 - 3s/epoch - 329ms/step
# Epoch 23/150
# 9/9 - 3s - loss: 0.7830 - binary_accuracy: 0.6196 - val_loss: 0.5309 - val_binary_accuracy: 0.7353 - 3s/epoch - 327ms/step
# Epoch 24/150
# 9/9 - 3s - loss: 0.6573 - binary_accuracy: 0.6667 - val_loss: 0.5318 - val_binary_accuracy: 0.7206 - 3s/epoch - 319ms/step
# Epoch 25/150
# 9/9 - 3s - loss: 0.6657 - binary_accuracy: 0.6739 - val_loss: 0.5230 - val_binary_accuracy: 0.7647 - 3s/epoch - 322ms/step
# Epoch 26/150
# 9/9 - 3s - loss: 0.6655 - binary_accuracy: 0.6413 - val_loss: 0.5189 - val_binary_accuracy: 0.7794 - 3s/epoch - 359ms/step
# Epoch 27/150
# 9/9 - 3s - loss: 0.8276 - binary_accuracy: 0.5761 - val_loss: 0.5125 - val_binary_accuracy: 0.7500 - 3s/epoch - 336ms/step
# Epoch 28/150
# 9/9 - 3s - loss: 0.6496 - binary_accuracy: 0.6775 - val_loss: 0.5105 - val_binary_accuracy: 0.7794 - 3s/epoch - 323ms/step
# Epoch 29/150
# 9/9 - 3s - loss: 0.7568 - binary_accuracy: 0.6196 - val_loss: 0.5237 - val_binary_accuracy: 0.7353 - 3s/epoch - 318ms/step
# Epoch 30/150
# 9/9 - 3s - loss: 0.6736 - binary_accuracy: 0.6413 - val_loss: 0.5211 - val_binary_accuracy: 0.7206 - 3s/epoch - 311ms/step
# Epoch 31/150
# 9/9 - 3s - loss: 0.7197 - binary_accuracy: 0.6341 - val_loss: 0.5170 - val_binary_accuracy: 0.7353 - 3s/epoch - 316ms/step
# Epoch 32/150
# 9/9 - 3s - loss: 0.6911 - binary_accuracy: 0.6377 - val_loss: 0.5102 - val_binary_accuracy: 0.7647 - 3s/epoch - 318ms/step
# Epoch 33/150
# 9/9 - 3s - loss: 0.7093 - binary_accuracy: 0.6377 - val_loss: 0.4973 - val_binary_accuracy: 0.7941 - 3s/epoch - 343ms/step
# Epoch 34/150
# 9/9 - 3s - loss: 0.7055 - binary_accuracy: 0.6558 - val_loss: 0.5024 - val_binary_accuracy: 0.7794 - 3s/epoch - 343ms/step
# Epoch 35/150
# 9/9 - 3s - loss: 0.6780 - binary_accuracy: 0.6848 - val_loss: 0.5006 - val_binary_accuracy: 0.7794 - 3s/epoch - 330ms/step
# Epoch 36/150
# 9/9 - 3s - loss: 0.6637 - binary_accuracy: 0.6558 - val_loss: 0.5021 - val_binary_accuracy: 0.7647 - 3s/epoch - 319ms/step
# Epoch 37/150
# 9/9 - 3s - loss: 0.6918 - binary_accuracy: 0.6341 - val_loss: 0.4920 - val_binary_accuracy: 0.7941 - 3s/epoch - 340ms/step
# Epoch 38/150
# 9/9 - 3s - loss: 0.6947 - binary_accuracy: 0.6449 - val_loss: 0.4911 - val_binary_accuracy: 0.7941 - 3s/epoch - 323ms/step
# Epoch 39/150
# 9/9 - 3s - loss: 0.6168 - binary_accuracy: 0.6594 - val_loss: 0.4995 - val_binary_accuracy: 0.7647 - 3s/epoch - 322ms/step
# Epoch 40/150
# 9/9 - 3s - loss: 0.6746 - binary_accuracy: 0.6486 - val_loss: 0.4995 - val_binary_accuracy: 0.7647 - 3s/epoch - 310ms/step
# Epoch 41/150
# 9/9 - 3s - loss: 0.6524 - binary_accuracy: 0.6594 - val_loss: 0.4905 - val_binary_accuracy: 0.7794 - 3s/epoch - 312ms/step
# Epoch 42/150
# 9/9 - 3s - loss: 0.6833 - binary_accuracy: 0.6630 - val_loss: 0.4866 - val_binary_accuracy: 0.7794 - 3s/epoch - 309ms/step
# Epoch 43/150
# 9/9 - 3s - loss: 0.6162 - binary_accuracy: 0.6993 - val_loss: 0.4954 - val_binary_accuracy: 0.7647 - 3s/epoch - 310ms/step
# Epoch 44/150
# 9/9 - 3s - loss: 0.6847 - binary_accuracy: 0.6775 - val_loss: 0.4834 - val_binary_accuracy: 0.7941 - 3s/epoch - 307ms/step
# Epoch 45/150
# 9/9 - 3s - loss: 0.5787 - binary_accuracy: 0.7029 - val_loss: 0.4927 - val_binary_accuracy: 0.7647 - 3s/epoch - 309ms/step
# Epoch 46/150
# 9/9 - 3s - loss: 0.6733 - binary_accuracy: 0.6630 - val_loss: 0.4879 - val_binary_accuracy: 0.7794 - 3s/epoch - 309ms/step
# Epoch 47/150
# 9/9 - 3s - loss: 0.7179 - binary_accuracy: 0.6558 - val_loss: 0.4969 - val_binary_accuracy: 0.7647 - 3s/epoch - 310ms/step
# Epoch 48/150
# 9/9 - 3s - loss: 0.7161 - binary_accuracy: 0.6486 - val_loss: 0.4890 - val_binary_accuracy: 0.7647 - 3s/epoch - 308ms/step
# Epoch 49/150
# 9/9 - 3s - loss: 0.5666 - binary_accuracy: 0.7101 - val_loss: 0.4752 - val_binary_accuracy: 0.7941 - 3s/epoch - 307ms/step
# Epoch 50/150
# 9/9 - 3s - loss: 0.6649 - binary_accuracy: 0.6920 - val_loss: 0.4756 - val_binary_accuracy: 0.7647 - 3s/epoch - 318ms/step
# Epoch 51/150
# 9/9 - 3s - loss: 0.6402 - binary_accuracy: 0.6920 - val_loss: 0.4855 - val_binary_accuracy: 0.7794 - 3s/epoch - 321ms/step
# Epoch 52/150
# 9/9 - 3s - loss: 0.6380 - binary_accuracy: 0.6667 - val_loss: 0.4875 - val_binary_accuracy: 0.7647 - 3s/epoch - 316ms/step
# Epoch 53/150
# 9/9 - 3s - loss: 0.6626 - binary_accuracy: 0.6957 - val_loss: 0.4920 - val_binary_accuracy: 0.7647 - 3s/epoch - 313ms/step
# Epoch 54/150
# 9/9 - 3s - loss: 0.6166 - binary_accuracy: 0.6920 - val_loss: 0.4865 - val_binary_accuracy: 0.7647 - 3s/epoch - 316ms/step
# Epoch 55/150
# 9/9 - 3s - loss: 0.6175 - binary_accuracy: 0.6703 - val_loss: 0.4938 - val_binary_accuracy: 0.7647 - 3s/epoch - 315ms/step
# Epoch 56/150
# 9/9 - 3s - loss: 0.6223 - binary_accuracy: 0.6812 - val_loss: 0.4777 - val_binary_accuracy: 0.7794 - 3s/epoch - 310ms/step
# Epoch 57/150
# 9/9 - 3s - loss: 0.6478 - binary_accuracy: 0.6630 - val_loss: 0.4724 - val_binary_accuracy: 0.7941 - 3s/epoch - 317ms/step
# Epoch 58/150
# 9/9 - 3s - loss: 0.6266 - binary_accuracy: 0.6884 - val_loss: 0.4883 - val_binary_accuracy: 0.7647 - 3s/epoch - 323ms/step
# Epoch 59/150
# 9/9 - 3s - loss: 0.6474 - binary_accuracy: 0.6848 - val_loss: 0.5235 - val_binary_accuracy: 0.7500 - 3s/epoch - 323ms/step
# Epoch 60/150
# 9/9 - 3s - loss: 0.6544 - binary_accuracy: 0.6667 - val_loss: 0.4927 - val_binary_accuracy: 0.7500 - 3s/epoch - 330ms/step
# Epoch 61/150
# 9/9 - 3s - loss: 0.6263 - binary_accuracy: 0.6558 - val_loss: 0.4751 - val_binary_accuracy: 0.7794 - 3s/epoch - 336ms/step
# Epoch 62/150
# 9/9 - 3s - loss: 0.5590 - binary_accuracy: 0.7283 - val_loss: 0.4687 - val_binary_accuracy: 0.7794 - 3s/epoch - 330ms/step
# Epoch 63/150
# 9/9 - 3s - loss: 0.6312 - binary_accuracy: 0.6957 - val_loss: 0.4671 - val_binary_accuracy: 0.7794 - 3s/epoch - 329ms/step
# Epoch 64/150
# 9/9 - 3s - loss: 0.6483 - binary_accuracy: 0.6667 - val_loss: 0.4852 - val_binary_accuracy: 0.7794 - 3s/epoch - 323ms/step
# Epoch 65/150
# 9/9 - 3s - loss: 0.6179 - binary_accuracy: 0.6993 - val_loss: 0.4781 - val_binary_accuracy: 0.7794 - 3s/epoch - 326ms/step
# Epoch 66/150
# 9/9 - 3s - loss: 0.6497 - binary_accuracy: 0.6703 - val_loss: 0.4592 - val_binary_accuracy: 0.7941 - 3s/epoch - 316ms/step
# Epoch 67/150
# 9/9 - 3s - loss: 0.6119 - binary_accuracy: 0.7065 - val_loss: 0.4589 - val_binary_accuracy: 0.7941 - 3s/epoch - 327ms/step
# Epoch 68/150
# 9/9 - 3s - loss: 0.6543 - binary_accuracy: 0.6775 - val_loss: 0.4609 - val_binary_accuracy: 0.7794 - 3s/epoch - 317ms/step
# Epoch 69/150
# 9/9 - 3s - loss: 0.6439 - binary_accuracy: 0.6594 - val_loss: 0.4705 - val_binary_accuracy: 0.7941 - 3s/epoch - 311ms/step
# Epoch 70/150
# 9/9 - 3s - loss: 0.5913 - binary_accuracy: 0.7174 - val_loss: 0.4740 - val_binary_accuracy: 0.7794 - 3s/epoch - 314ms/step
# Epoch 71/150
# 9/9 - 3s - loss: 0.5851 - binary_accuracy: 0.7319 - val_loss: 0.4743 - val_binary_accuracy: 0.7794 - 3s/epoch - 314ms/step
# Epoch 72/150
# 9/9 - 3s - loss: 0.5712 - binary_accuracy: 0.7065 - val_loss: 0.4606 - val_binary_accuracy: 0.7941 - 3s/epoch - 313ms/step
# Epoch 73/150
# 9/9 - 3s - loss: 0.5590 - binary_accuracy: 0.7246 - val_loss: 0.4536 - val_binary_accuracy: 0.7941 - 3s/epoch - 317ms/step
# Epoch 74/150
# 9/9 - 3s - loss: 0.5966 - binary_accuracy: 0.7138 - val_loss: 0.4541 - val_binary_accuracy: 0.7941 - 3s/epoch - 311ms/step
# Epoch 75/150
# 9/9 - 3s - loss: 0.5467 - binary_accuracy: 0.7210 - val_loss: 0.4682 - val_binary_accuracy: 0.7941 - 3s/epoch - 315ms/step
# Epoch 76/150
# 9/9 - 3s - loss: 0.5643 - binary_accuracy: 0.6848 - val_loss: 0.4612 - val_binary_accuracy: 0.7941 - 3s/epoch - 313ms/step
# Epoch 77/150
# 9/9 - 3s - loss: 0.6177 - binary_accuracy: 0.7210 - val_loss: 0.4611 - val_binary_accuracy: 0.7941 - 3s/epoch - 313ms/step
# Epoch 78/150
# 9/9 - 3s - loss: 0.5862 - binary_accuracy: 0.7138 - val_loss: 0.4625 - val_binary_accuracy: 0.7941 - 3s/epoch - 313ms/step
# Epoch 79/150
# 9/9 - 3s - loss: 0.5554 - binary_accuracy: 0.7138 - val_loss: 0.4576 - val_binary_accuracy: 0.7941 - 3s/epoch - 313ms/step
# Epoch 80/150
# 9/9 - 3s - loss: 0.6362 - binary_accuracy: 0.6486 - val_loss: 0.4419 - val_binary_accuracy: 0.8088 - 3s/epoch - 329ms/step
# Epoch 81/150
# 9/9 - 3s - loss: 0.6038 - binary_accuracy: 0.6920 - val_loss: 0.4444 - val_binary_accuracy: 0.8088 - 3s/epoch - 308ms/step
# Epoch 82/150
# 9/9 - 3s - loss: 0.5410 - binary_accuracy: 0.7536 - val_loss: 0.4466 - val_binary_accuracy: 0.8088 - 3s/epoch - 316ms/step
# Epoch 83/150
# 9/9 - 3s - loss: 0.5739 - binary_accuracy: 0.6667 - val_loss: 0.4502 - val_binary_accuracy: 0.7941 - 3s/epoch - 310ms/step
# Epoch 84/150
# 9/9 - 3s - loss: 0.6029 - binary_accuracy: 0.7029 - val_loss: 0.4537 - val_binary_accuracy: 0.7941 - 3s/epoch - 314ms/step
# Epoch 85/150
# 9/9 - 3s - loss: 0.5299 - binary_accuracy: 0.7391 - val_loss: 0.4588 - val_binary_accuracy: 0.7941 - 3s/epoch - 316ms/step
# Epoch 86/150
# 9/9 - 3s - loss: 0.5825 - binary_accuracy: 0.7428 - val_loss: 0.4618 - val_binary_accuracy: 0.7794 - 3s/epoch - 319ms/step
# Epoch 87/150
# 9/9 - 3s - loss: 0.4840 - binary_accuracy: 0.7572 - val_loss: 0.4469 - val_binary_accuracy: 0.8088 - 3s/epoch - 321ms/step
# Epoch 88/150
# 9/9 - 3s - loss: 0.5621 - binary_accuracy: 0.7029 - val_loss: 0.4457 - val_binary_accuracy: 0.8088 - 3s/epoch - 323ms/step
# Epoch 89/150
# 9/9 - 3s - loss: 0.6054 - binary_accuracy: 0.6993 - val_loss: 0.4497 - val_binary_accuracy: 0.7941 - 3s/epoch - 335ms/step
# Epoch 90/150
# 9/9 - 3s - loss: 0.6452 - binary_accuracy: 0.7029 - val_loss: 0.4464 - val_binary_accuracy: 0.8088 - 3s/epoch - 339ms/step
# Epoch 91/150
# 9/9 - 3s - loss: 0.6316 - binary_accuracy: 0.6739 - val_loss: 0.4624 - val_binary_accuracy: 0.7794 - 3s/epoch - 329ms/step
# Epoch 92/150
# 9/9 - 3s - loss: 0.5695 - binary_accuracy: 0.7174 - val_loss: 0.4545 - val_binary_accuracy: 0.8088 - 3s/epoch - 331ms/step
# Epoch 93/150
# 9/9 - 3s - loss: 0.5208 - binary_accuracy: 0.7464 - val_loss: 0.4520 - val_binary_accuracy: 0.8088 - 3s/epoch - 326ms/step
# Epoch 94/150
# 9/9 - 3s - loss: 0.5694 - binary_accuracy: 0.7174 - val_loss: 0.4589 - val_binary_accuracy: 0.7794 - 3s/epoch - 326ms/step
# Epoch 95/150
# 9/9 - 3s - loss: 0.5612 - binary_accuracy: 0.7101 - val_loss: 0.4471 - val_binary_accuracy: 0.8235 - 3s/epoch - 348ms/step
# Epoch 96/150
# 9/9 - 3s - loss: 0.5726 - binary_accuracy: 0.7210 - val_loss: 0.4426 - val_binary_accuracy: 0.8088 - 3s/epoch - 332ms/step
# Epoch 97/150
# 9/9 - 3s - loss: 0.5481 - binary_accuracy: 0.7391 - val_loss: 0.4494 - val_binary_accuracy: 0.8088 - 3s/epoch - 329ms/step
# Epoch 98/150
# 9/9 - 3s - loss: 0.5903 - binary_accuracy: 0.7174 - val_loss: 0.4323 - val_binary_accuracy: 0.8235 - 3s/epoch - 322ms/step
# Epoch 99/150
# 9/9 - 3s - loss: 0.5883 - binary_accuracy: 0.7174 - val_loss: 0.4534 - val_binary_accuracy: 0.7794 - 3s/epoch - 326ms/step
# Epoch 100/150
# 9/9 - 3s - loss: 0.6029 - binary_accuracy: 0.6957 - val_loss: 0.4288 - val_binary_accuracy: 0.8382 - 3s/epoch - 344ms/step
# Epoch 101/150
# 9/9 - 3s - loss: 0.5713 - binary_accuracy: 0.6812 - val_loss: 0.4535 - val_binary_accuracy: 0.7794 - 3s/epoch - 336ms/step
# Epoch 102/150
# 9/9 - 3s - loss: 0.6257 - binary_accuracy: 0.6920 - val_loss: 0.4756 - val_binary_accuracy: 0.7647 - 3s/epoch - 318ms/step
# Epoch 103/150
# 9/9 - 3s - loss: 0.5528 - binary_accuracy: 0.7391 - val_loss: 0.4406 - val_binary_accuracy: 0.8235 - 3s/epoch - 316ms/step
# Epoch 104/150
# 9/9 - 3s - loss: 0.5317 - binary_accuracy: 0.7138 - val_loss: 0.4345 - val_binary_accuracy: 0.8088 - 3s/epoch - 322ms/step
# Epoch 105/150
# 9/9 - 3s - loss: 0.5213 - binary_accuracy: 0.7428 - val_loss: 0.4245 - val_binary_accuracy: 0.8382 - 3s/epoch - 316ms/step
# Epoch 106/150
# 9/9 - 3s - loss: 0.5337 - binary_accuracy: 0.7029 - val_loss: 0.4354 - val_binary_accuracy: 0.8235 - 3s/epoch - 320ms/step
# Epoch 107/150
# 9/9 - 3s - loss: 0.5852 - binary_accuracy: 0.6993 - val_loss: 0.4259 - val_binary_accuracy: 0.8382 - 3s/epoch - 320ms/step
# Epoch 108/150
# 9/9 - 3s - loss: 0.5671 - binary_accuracy: 0.7174 - val_loss: 0.4634 - val_binary_accuracy: 0.7794 - 3s/epoch - 316ms/step
# Epoch 109/150
# 9/9 - 3s - loss: 0.5385 - binary_accuracy: 0.7355 - val_loss: 0.4355 - val_binary_accuracy: 0.8235 - 3s/epoch - 319ms/step
# Epoch 110/150
# 9/9 - 3s - loss: 0.5223 - binary_accuracy: 0.7355 - val_loss: 0.4368 - val_binary_accuracy: 0.8235 - 3s/epoch - 327ms/step
# Epoch 111/150
# 9/9 - 3s - loss: 0.5635 - binary_accuracy: 0.7283 - val_loss: 0.4422 - val_binary_accuracy: 0.7941 - 3s/epoch - 319ms/step
# Epoch 112/150
# 9/9 - 3s - loss: 0.5967 - binary_accuracy: 0.7174 - val_loss: 0.4203 - val_binary_accuracy: 0.8382 - 3s/epoch - 323ms/step
# Epoch 113/150
# 9/9 - 3s - loss: 0.5378 - binary_accuracy: 0.7645 - val_loss: 0.4220 - val_binary_accuracy: 0.8382 - 3s/epoch - 317ms/step
# Epoch 114/150
# 9/9 - 3s - loss: 0.5288 - binary_accuracy: 0.7899 - val_loss: 0.4246 - val_binary_accuracy: 0.8382 - 3s/epoch - 317ms/step
# Epoch 115/150
# 9/9 - 3s - loss: 0.5141 - binary_accuracy: 0.7319 - val_loss: 0.4268 - val_binary_accuracy: 0.8235 - 3s/epoch - 325ms/step
# Epoch 116/150
# 9/9 - 3s - loss: 0.5740 - binary_accuracy: 0.7138 - val_loss: 0.4489 - val_binary_accuracy: 0.7794 - 3s/epoch - 321ms/step
# Epoch 117/150
# 9/9 - 3s - loss: 0.5397 - binary_accuracy: 0.7536 - val_loss: 0.4215 - val_binary_accuracy: 0.8382 - 3s/epoch - 319ms/step
# Epoch 118/150
# 9/9 - 3s - loss: 0.5443 - binary_accuracy: 0.7065 - val_loss: 0.4198 - val_binary_accuracy: 0.8382 - 3s/epoch - 320ms/step
# Epoch 119/150
# 9/9 - 3s - loss: 0.5677 - binary_accuracy: 0.7065 - val_loss: 0.4249 - val_binary_accuracy: 0.8382 - 3s/epoch - 318ms/step
# Epoch 120/150
# 9/9 - 3s - loss: 0.5110 - binary_accuracy: 0.7428 - val_loss: 0.4352 - val_binary_accuracy: 0.8088 - 3s/epoch - 316ms/step
# Epoch 121/150
# 9/9 - 3s - loss: 0.4883 - binary_accuracy: 0.7790 - val_loss: 0.4388 - val_binary_accuracy: 0.8088 - 3s/epoch - 320ms/step
# Epoch 122/150
# 9/9 - 3s - loss: 0.5021 - binary_accuracy: 0.7645 - val_loss: 0.4323 - val_binary_accuracy: 0.8382 - 3s/epoch - 322ms/step
# Epoch 123/150
# 9/9 - 3s - loss: 0.5369 - binary_accuracy: 0.7500 - val_loss: 0.4363 - val_binary_accuracy: 0.8088 - 3s/epoch - 321ms/step
# Epoch 124/150
# 9/9 - 3s - loss: 0.5740 - binary_accuracy: 0.6884 - val_loss: 0.4284 - val_binary_accuracy: 0.8382 - 3s/epoch - 323ms/step
# Epoch 125/150
# 9/9 - 3s - loss: 0.5530 - binary_accuracy: 0.6957 - val_loss: 0.4321 - val_binary_accuracy: 0.8235 - 3s/epoch - 325ms/step
# Epoch 126/150
# 9/9 - 3s - loss: 0.6087 - binary_accuracy: 0.6993 - val_loss: 0.4456 - val_binary_accuracy: 0.7794 - 3s/epoch - 317ms/step
# Epoch 127/150
# 9/9 - 3s - loss: 0.5260 - binary_accuracy: 0.7500 - val_loss: 0.4146 - val_binary_accuracy: 0.8529 - 3s/epoch - 354ms/step
# Epoch 128/150
# 9/9 - 3s - loss: 0.4929 - binary_accuracy: 0.7536 - val_loss: 0.4198 - val_binary_accuracy: 0.8382 - 3s/epoch - 330ms/step
# Epoch 129/150
# 9/9 - 3s - loss: 0.4972 - binary_accuracy: 0.7645 - val_loss: 0.4271 - val_binary_accuracy: 0.8529 - 3s/epoch - 319ms/step
# Epoch 130/150
# 9/9 - 3s - loss: 0.5278 - binary_accuracy: 0.7428 - val_loss: 0.4197 - val_binary_accuracy: 0.8382 - 3s/epoch - 320ms/step
# Epoch 131/150
# 9/9 - 3s - loss: 0.5661 - binary_accuracy: 0.7210 - val_loss: 0.4216 - val_binary_accuracy: 0.8382 - 3s/epoch - 321ms/step
# Epoch 132/150
# 9/9 - 3s - loss: 0.5244 - binary_accuracy: 0.7319 - val_loss: 0.4280 - val_binary_accuracy: 0.8529 - 3s/epoch - 319ms/step
# Epoch 133/150
# 9/9 - 3s - loss: 0.5345 - binary_accuracy: 0.7355 - val_loss: 0.4269 - val_binary_accuracy: 0.8382 - 3s/epoch - 319ms/step
# Epoch 134/150
# 9/9 - 3s - loss: 0.4958 - binary_accuracy: 0.7428 - val_loss: 0.4394 - val_binary_accuracy: 0.8088 - 3s/epoch - 321ms/step
# Epoch 135/150
# 9/9 - 3s - loss: 0.5266 - binary_accuracy: 0.7645 - val_loss: 0.4267 - val_binary_accuracy: 0.8382 - 3s/epoch - 316ms/step
# Epoch 136/150
# 9/9 - 3s - loss: 0.5098 - binary_accuracy: 0.7464 - val_loss: 0.4334 - val_binary_accuracy: 0.8235 - 3s/epoch - 321ms/step
# Epoch 137/150
# 9/9 - 3s - loss: 0.5115 - binary_accuracy: 0.7210 - val_loss: 0.4097 - val_binary_accuracy: 0.8529 - 3s/epoch - 327ms/step
# Epoch 138/150
# 9/9 - 3s - loss: 0.5023 - binary_accuracy: 0.7464 - val_loss: 0.4106 - val_binary_accuracy: 0.8529 - 3s/epoch - 315ms/step
# Epoch 139/150
# 9/9 - 3s - loss: 0.4816 - binary_accuracy: 0.7754 - val_loss: 0.4149 - val_binary_accuracy: 0.8382 - 3s/epoch - 317ms/step
# Epoch 140/150
# 9/9 - 3s - loss: 0.5141 - binary_accuracy: 0.7464 - val_loss: 0.4221 - val_binary_accuracy: 0.8382 - 3s/epoch - 319ms/step
# Epoch 141/150
# 9/9 - 3s - loss: 0.4993 - binary_accuracy: 0.7681 - val_loss: 0.4278 - val_binary_accuracy: 0.8382 - 3s/epoch - 314ms/step
# Epoch 142/150
# 9/9 - 3s - loss: 0.4778 - binary_accuracy: 0.7754 - val_loss: 0.4166 - val_binary_accuracy: 0.8529 - 3s/epoch - 320ms/step
# Epoch 143/150
# 9/9 - 3s - loss: 0.4813 - binary_accuracy: 0.7428 - val_loss: 0.4240 - val_binary_accuracy: 0.8382 - 3s/epoch - 317ms/step
# Epoch 144/150
# 9/9 - 3s - loss: 0.4803 - binary_accuracy: 0.7717 - val_loss: 0.4058 - val_binary_accuracy: 0.8529 - 3s/epoch - 320ms/step
# Epoch 145/150
# 9/9 - 3s - loss: 0.5356 - binary_accuracy: 0.7572 - val_loss: 0.4228 - val_binary_accuracy: 0.8382 - 3s/epoch - 320ms/step
# Epoch 146/150
# 9/9 - 3s - loss: 0.5091 - binary_accuracy: 0.7500 - val_loss: 0.4203 - val_binary_accuracy: 0.8382 - 3s/epoch - 325ms/step
# Epoch 147/150
# 9/9 - 3s - loss: 0.4751 - binary_accuracy: 0.7790 - val_loss: 0.4127 - val_binary_accuracy: 0.8529 - 3s/epoch - 318ms/step
# Epoch 148/150
# 9/9 - 3s - loss: 0.5127 - binary_accuracy: 0.7609 - val_loss: 0.4090 - val_binary_accuracy: 0.8382 - 3s/epoch - 318ms/step
# Epoch 149/150
# 9/9 - 3s - loss: 0.5295 - binary_accuracy: 0.7138 - val_loss: 0.4137 - val_binary_accuracy: 0.8529 - 3s/epoch - 320ms/step
# Epoch 150/150
# 9/9 - 3s - loss: 0.5625 - binary_accuracy: 0.7355 - val_loss: 0.4015 - val_binary_accuracy: 0.8529 - 3s/epoch - 316ms/step

# %%
#accuracy
plt.plot(result.history['binary_accuracy'])
plt.plot(result.history['val_binary_accuracy'])
# plt.plot(result.history['accuracy'])
# plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# OPTIONAL: Decide if best weights should be loaded from previous model based on val_acc
# The model weights (that are considered the best) are loaded into the model.
result = model.load_weights(checkpoint_filepath)

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model
model.save("Models/MobileNet/MobileNet_covid_classification.h5")

os.chdir(destination)

# %% [markdown]
# <h3>Evaluate Test data</h3>

# %%
print(sum(cb.logs) / 150)

testLoss, testAcc = model.evaluate(test)
print('''
Test Loss: {}
Test Accuracy: {}
'''.format(testLoss, testAcc))
# Out:
# 2.976599264666681
# 3/3 [==============================] - 1s 342ms/step - loss: 0.4594 - binary_accuracy: 0.7907
#
# Test Loss: 0.45939236879348755
# Test Accuracy: 0.7906976938247681

# %% [markdown]
# <h4>*Optional - Fine tune model with two-step training*</h4>

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

mobile.trainable = True

for layer in mobile.layers[:-2]:
    layer.trainable = False
    
#re-train the model at a very low learning rate
model.compile(optimizer=Adam(learning_rate=0.00006), loss='binary_crossentropy', metrics=['binary_accuracy'])

result = model.fit(x=train, validation_data=validation, epochs=100, verbose=2, callbacks=[cb, es])
# Out:
# Epoch 1/100
# 9/9 - 5s - loss: 0.5285 - binary_accuracy: 0.7428 - val_loss: 0.4195 - val_binary_accuracy: 0.8382 - 5s/epoch - 531ms/step
# Epoch 2/100
# 9/9 - 3s - loss: 0.4989 - binary_accuracy: 0.7609 - val_loss: 0.4194 - val_binary_accuracy: 0.8382 - 3s/epoch - 328ms/step
# Epoch 3/100
# 9/9 - 3s - loss: 0.5094 - binary_accuracy: 0.7500 - val_loss: 0.4188 - val_binary_accuracy: 0.8382 - 3s/epoch - 319ms/step
# Epoch 4/100
# 9/9 - 3s - loss: 0.5709 - binary_accuracy: 0.7246 - val_loss: 0.4208 - val_binary_accuracy: 0.8382 - 3s/epoch - 315ms/step
# Epoch 5/100
# 9/9 - 3s - loss: 0.5043 - binary_accuracy: 0.7391 - val_loss: 0.4201 - val_binary_accuracy: 0.8382 - 3s/epoch - 321ms/step
# Epoch 6/100
# 9/9 - 3s - loss: 0.5170 - binary_accuracy: 0.7319 - val_loss: 0.4229 - val_binary_accuracy: 0.8529 - 3s/epoch - 320ms/step
# Epoch 7/100
# 9/9 - 3s - loss: 0.5079 - binary_accuracy: 0.7717 - val_loss: 0.4233 - val_binary_accuracy: 0.8529 - 3s/epoch - 315ms/step
# Epoch 8/100
# 9/9 - 3s - loss: 0.5608 - binary_accuracy: 0.6957 - val_loss: 0.4231 - val_binary_accuracy: 0.8529 - 3s/epoch - 321ms/step
# Epoch 9/100
# 9/9 - 3s - loss: 0.4878 - binary_accuracy: 0.7645 - val_loss: 0.4242 - val_binary_accuracy: 0.8529 - 3s/epoch - 343ms/step
# Epoch 10/100
# 9/9 - 3s - loss: 0.5048 - binary_accuracy: 0.7536 - val_loss: 0.4273 - val_binary_accuracy: 0.8529 - 3s/epoch - 321ms/step
# Epoch 11/100
# 9/9 - 3s - loss: 0.5239 - binary_accuracy: 0.7464 - val_loss: 0.4273 - val_binary_accuracy: 0.8529 - 3s/epoch - 321ms/step
# Epoch 12/100
# 9/9 - 3s - loss: 0.5079 - binary_accuracy: 0.7355 - val_loss: 0.4270 - val_binary_accuracy: 0.8529 - 3s/epoch - 324ms/step
# Epoch 13/100
# 9/9 - 3s - loss: 0.5184 - binary_accuracy: 0.7319 - val_loss: 0.4245 - val_binary_accuracy: 0.8529 - 3s/epoch - 320ms/step
# Epoch 13: early stopping

# %% [markdown]
# <h3>Accuracy and Loss graph</h3>

# %%
#accuracy
plt.plot(result.history['binary_accuracy'])
plt.plot(result.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# <h3>Classification report</h3>

# %%
predictions = model.predict(test, verbose=0)
# predictions = predictions.reshape(1,-1)[0]
# lst = np.argmax(predictions, axis= 1)
lst = (predictions > 0.5).astype(int)

print(classification_report(test.classes, lst, target_names = test.class_indices))
# Out:
#               precision    recall  f1-score   support
#
#        covid       0.77      0.56      0.65        36
#       normal       0.73      0.88      0.80        50
#
#     accuracy                           0.74        86
#    macro avg       0.75      0.72      0.72        86
# weighted avg       0.75      0.74      0.74        86

# %% [markdown]
# <h3>Confusion matrix</h3>

# %%
result = confusion_matrix(test.classes, lst)
print(result)

def plot_confusion_matrix(result, classes, cmap=plt.cm.Blues):
    plt.subplots(figsize=(7, 7))
    plt.imshow(result, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

    thresh = result.max() / 2.
    for i, j in itertools.product(range(result.shape[0]), range(result.shape[1])):
        plt.text(j, i, result[i, j],
            horizontalalignment="center",
            color = "white" if result[i, j] > thresh else "black")
        
    #current matplotlib version will cut off top and bottom of the matrix, 
    #hence the manual workaround - remove if matplotlib version does not cut off
    b, t = plt.ylim() # discover bottom and top values
    b += 0.5 # Add 0.5 to bottom
    t -= 0.5 # Subtract 0.5 from top
    plt.ylim(b, t) # update ylim(bottom, top) values
    plt.show()
    
plot_confusion_matrix(result, list(test.class_indices.keys()))
# Out:
# [[20 16]
#  [ 6 44]]

# %% [markdown]
# <h3>Save the model</h3>

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model
model.save("Models/MobileNet/MobileNet_covid_classification_finetuned.h5")
