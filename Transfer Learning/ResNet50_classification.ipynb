# %% [markdown]
# <h3>Import packages</h3>

# %%
from datetime import date
from timeit import default_timer as timer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
# from keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import imagenet_utils
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Configure TensorFlow to use GPU for training
tf.config.list_physical_devices('GPU') 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_physical_devices('GPU')
#Set GPU memory limit so my GPU doesn't crash
if gpus:
    try:
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <h3>Create class to record time taken to train the model</h3>

# %%
#class to record time taken to train per epoch
class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

# %% [markdown]
# <h3>Create train and test folder</h3>

# %%
#creates a folder each time the set of code is run to sort dataset into train and test
day = date.today()
formatDate = day.strftime("%b-%d-%Y")

#create folder with current date to group predictions ran in a day together, if it does not exists
if os.path.isdir('Prediction (' + formatDate + ')') is False:
    folder = os.mkdir('Prediction (' + formatDate + ')')
folder = 'Prediction (' + formatDate + ')'

#looping through to find if destination folder exists
i = 1
while True:
    if os.path.isdir(folder + '/dataset_6 - ' + str(i)) is False:
        break
    i += 1

#destination path for unsorted folder
destination = folder + '/dataset_6 - ' + str(i)

#source path for unsorted folder
source = 'dataset_6/'

#duplicate the unsorted folder from source to destination
shutil.copytree(source, destination)

os.mkdir(destination + '/train')
os.mkdir(destination + '/test')

# %% [markdown]
# <h3>Sort dataset into train and test folder</h3>

# %%
#function to split images into training (80%) and testing (20%) and return both
def split(data):
    num = int(len(data) * 0.8)
    # num = int(len(data) * 0.9) #90/10 split
#     num = int(len(data) * 0.7) #70/30 split
    random.shuffle(data)
    return data[:num], data[num:]

dir = os.chdir(destination)
for category in os.listdir(dir):
    #skip the iteration if folder is "train" or "test"
    skip = ['train', 'test']
    if category in skip:
        continue
    
    shutil.move(f'{category}', 'train')
    #create a subfolder with the same name in test
    os.mkdir(f'test/{category}')

    #get the images in each folder (battery type) for spltting of data into training and testing
    img = os.listdir(f'train/{category}')
    training, testing = split(img)
    
    for file in testing:
        shutil.move(f'train/{category}/{file}', f'test/{category}')

# %% [markdown]
# <h3>Transfer Learning</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.ResNet50(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %%
mobile.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
for layer in mobile.layers[:-2]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))
x = mobile(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(1, activation="sigmoid")(x)  

model = keras.Model(inputs, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 23,589,761
# Trainable params: 2,049
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# <h3>Process data</h3>

# %%
train_path = 'train'
test_path = 'test'

#for data augmentation on training data
datagen = ImageDataGenerator( 
    preprocessing_function =tf.keras.applications.resnet50.preprocess_input,
    validation_split=0.2,
    # validation_split=0.1, #changes made for 90/10 split
    rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.2, # Randomly zoom image 
    width_shift_range = 0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range = 0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip = True,  # randomly flip images
#     vertical_flip = False,    # randomly flip images
    vertical_flip = True, #include vertical flip for better generalisation
    )  

#takes images from directory path and generates batches of augmented data
train = datagen.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    class_mode = 'binary',
    batch_size=32,
    subset='training',
        shuffle = False)

#for validation data
validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input, 
                                        validation_split=0.2)
# validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
#                                         validation_split=0.1) #changes made for 90/10 split


validation = validation_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    class_mode = 'binary',
    batch_size=32,
    subset='validation',
        shuffle = False)

#for test data
test = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input)\
.flow_from_directory(directory=test_path, target_size=(224,224), class_mode = 'binary', batch_size=32, shuffle=False)
# Out:
# Found 276 images belonging to 2 classes.
# Found 68 images belonging to 2 classes.
# Found 86 images belonging to 2 classes.

# %% [markdown]
# <h3>Train model</h3>

# %%
model.compile(optimizer=Adam(learning_rate=0.0006), loss='binary_crossentropy', metrics=['binary_accuracy']) #Last best setting
# model.compile(optimizer=Adam(learning_rate=0.006), loss='binary_crossentropy', metrics=['accuracy']) #Last best setting
checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_binary_accuracy',
    # monitor='val_accuracy',
    mode='max',
    save_best_only=True) #save best model

#more epochs for better results
result = model.fit(x=train, validation_data=validation, epochs=150, verbose=2, callbacks=[model_checkpoint_callback,cb])
# Out:
# Epoch 1/150
# 9/9 - 20s - loss: 1.1429 - binary_accuracy: 0.4674 - val_loss: 0.7064 - val_binary_accuracy: 0.6176 - 20s/epoch - 2s/step
# Epoch 2/150
# 9/9 - 5s - loss: 0.8871 - binary_accuracy: 0.5543 - val_loss: 0.6642 - val_binary_accuracy: 0.6912 - 5s/epoch - 568ms/step
# Epoch 3/150
# 9/9 - 5s - loss: 0.8035 - binary_accuracy: 0.5507 - val_loss: 0.6073 - val_binary_accuracy: 0.7059 - 5s/epoch - 550ms/step
# Epoch 4/150
# 9/9 - 3s - loss: 0.7537 - binary_accuracy: 0.6159 - val_loss: 0.5765 - val_binary_accuracy: 0.6765 - 3s/epoch - 346ms/step
# Epoch 5/150
# 9/9 - 3s - loss: 0.6279 - binary_accuracy: 0.6739 - val_loss: 0.5612 - val_binary_accuracy: 0.7059 - 3s/epoch - 345ms/step
# Epoch 6/150
# 9/9 - 5s - loss: 0.7563 - binary_accuracy: 0.6014 - val_loss: 0.5575 - val_binary_accuracy: 0.7353 - 5s/epoch - 557ms/step
# Epoch 7/150
# 9/9 - 5s - loss: 0.6574 - binary_accuracy: 0.6449 - val_loss: 0.5288 - val_binary_accuracy: 0.7500 - 5s/epoch - 508ms/step
# Epoch 8/150
# 9/9 - 3s - loss: 0.6048 - binary_accuracy: 0.7029 - val_loss: 0.5202 - val_binary_accuracy: 0.7206 - 3s/epoch - 357ms/step
# Epoch 9/150
# 9/9 - 4s - loss: 0.6115 - binary_accuracy: 0.6486 - val_loss: 0.5239 - val_binary_accuracy: 0.7941 - 4s/epoch - 493ms/step
# Epoch 10/150
# 9/9 - 3s - loss: 0.5956 - binary_accuracy: 0.7029 - val_loss: 0.5088 - val_binary_accuracy: 0.7647 - 3s/epoch - 349ms/step
# Epoch 11/150
# 9/9 - 3s - loss: 0.5677 - binary_accuracy: 0.7391 - val_loss: 0.5018 - val_binary_accuracy: 0.7500 - 3s/epoch - 355ms/step
# Epoch 12/150
# 9/9 - 3s - loss: 0.5688 - binary_accuracy: 0.7101 - val_loss: 0.5000 - val_binary_accuracy: 0.7941 - 3s/epoch - 352ms/step
# Epoch 13/150
# 9/9 - 3s - loss: 0.6070 - binary_accuracy: 0.7029 - val_loss: 0.4919 - val_binary_accuracy: 0.7647 - 3s/epoch - 343ms/step
# Epoch 14/150
# 9/9 - 3s - loss: 0.5522 - binary_accuracy: 0.7609 - val_loss: 0.5166 - val_binary_accuracy: 0.7794 - 3s/epoch - 354ms/step
# Epoch 15/150
# 9/9 - 3s - loss: 0.5140 - binary_accuracy: 0.7428 - val_loss: 0.4910 - val_binary_accuracy: 0.7941 - 3s/epoch - 343ms/step
# Epoch 16/150
# 9/9 - 3s - loss: 0.5146 - binary_accuracy: 0.7246 - val_loss: 0.4786 - val_binary_accuracy: 0.7794 - 3s/epoch - 345ms/step
# Epoch 17/150
# 9/9 - 3s - loss: 0.4886 - binary_accuracy: 0.7862 - val_loss: 0.4755 - val_binary_accuracy: 0.7794 - 3s/epoch - 347ms/step
# Epoch 18/150
# 9/9 - 3s - loss: 0.5264 - binary_accuracy: 0.7609 - val_loss: 0.4887 - val_binary_accuracy: 0.7941 - 3s/epoch - 342ms/step
# Epoch 19/150
# 9/9 - 4s - loss: 0.5107 - binary_accuracy: 0.7536 - val_loss: 0.4775 - val_binary_accuracy: 0.8088 - 4s/epoch - 407ms/step
# Epoch 20/150
# 9/9 - 3s - loss: 0.4785 - binary_accuracy: 0.7681 - val_loss: 0.4680 - val_binary_accuracy: 0.8088 - 3s/epoch - 344ms/step
# Epoch 21/150
# 9/9 - 3s - loss: 0.4637 - binary_accuracy: 0.7681 - val_loss: 0.4609 - val_binary_accuracy: 0.8088 - 3s/epoch - 357ms/step
# Epoch 22/150
# 9/9 - 3s - loss: 0.5262 - binary_accuracy: 0.7319 - val_loss: 0.4909 - val_binary_accuracy: 0.8088 - 3s/epoch - 353ms/step
# Epoch 23/150
# 9/9 - 3s - loss: 0.4402 - binary_accuracy: 0.8080 - val_loss: 0.4623 - val_binary_accuracy: 0.8088 - 3s/epoch - 376ms/step
# Epoch 24/150
# 9/9 - 3s - loss: 0.4474 - binary_accuracy: 0.8043 - val_loss: 0.4516 - val_binary_accuracy: 0.7941 - 3s/epoch - 349ms/step
# Epoch 25/150
# 9/9 - 3s - loss: 0.5112 - binary_accuracy: 0.7609 - val_loss: 0.4582 - val_binary_accuracy: 0.7941 - 3s/epoch - 348ms/step
# Epoch 26/150
# 9/9 - 3s - loss: 0.4472 - binary_accuracy: 0.7754 - val_loss: 0.4469 - val_binary_accuracy: 0.8088 - 3s/epoch - 353ms/step
# Epoch 27/150
# 9/9 - 3s - loss: 0.4552 - binary_accuracy: 0.8152 - val_loss: 0.4468 - val_binary_accuracy: 0.8088 - 3s/epoch - 348ms/step
# Epoch 28/150
# 9/9 - 3s - loss: 0.4762 - binary_accuracy: 0.7935 - val_loss: 0.4788 - val_binary_accuracy: 0.8088 - 3s/epoch - 342ms/step
# Epoch 29/150
# 9/9 - 3s - loss: 0.4683 - binary_accuracy: 0.7790 - val_loss: 0.4633 - val_binary_accuracy: 0.8088 - 3s/epoch - 339ms/step
# Epoch 30/150
# 9/9 - 3s - loss: 0.5170 - binary_accuracy: 0.7464 - val_loss: 0.4533 - val_binary_accuracy: 0.8088 - 3s/epoch - 345ms/step
# Epoch 31/150
# 9/9 - 3s - loss: 0.4224 - binary_accuracy: 0.7862 - val_loss: 0.4413 - val_binary_accuracy: 0.7941 - 3s/epoch - 339ms/step
# Epoch 32/150
# 9/9 - 3s - loss: 0.4585 - binary_accuracy: 0.7754 - val_loss: 0.4419 - val_binary_accuracy: 0.8088 - 3s/epoch - 345ms/step
# Epoch 33/150
# 9/9 - 4s - loss: 0.4644 - binary_accuracy: 0.8116 - val_loss: 0.4434 - val_binary_accuracy: 0.8235 - 4s/epoch - 478ms/step
# Epoch 34/150
# 9/9 - 3s - loss: 0.4494 - binary_accuracy: 0.7971 - val_loss: 0.4837 - val_binary_accuracy: 0.8235 - 3s/epoch - 339ms/step
# Epoch 35/150
# 9/9 - 3s - loss: 0.4365 - binary_accuracy: 0.8116 - val_loss: 0.4479 - val_binary_accuracy: 0.8235 - 3s/epoch - 346ms/step
# Epoch 36/150
# 9/9 - 3s - loss: 0.4382 - binary_accuracy: 0.8043 - val_loss: 0.4781 - val_binary_accuracy: 0.8088 - 3s/epoch - 348ms/step
# Epoch 37/150
# 9/9 - 4s - loss: 0.4124 - binary_accuracy: 0.7862 - val_loss: 0.4414 - val_binary_accuracy: 0.8382 - 4s/epoch - 492ms/step
# Epoch 38/150
# 9/9 - 3s - loss: 0.4005 - binary_accuracy: 0.8225 - val_loss: 0.4344 - val_binary_accuracy: 0.8088 - 3s/epoch - 343ms/step
# Epoch 39/150
# 9/9 - 3s - loss: 0.4218 - binary_accuracy: 0.8188 - val_loss: 0.4497 - val_binary_accuracy: 0.8235 - 3s/epoch - 347ms/step
# Epoch 40/150
# 9/9 - 3s - loss: 0.4414 - binary_accuracy: 0.8116 - val_loss: 0.4800 - val_binary_accuracy: 0.8088 - 3s/epoch - 348ms/step
# Epoch 41/150
# 9/9 - 3s - loss: 0.3439 - binary_accuracy: 0.8587 - val_loss: 0.4373 - val_binary_accuracy: 0.8235 - 3s/epoch - 348ms/step
# Epoch 42/150
# 9/9 - 3s - loss: 0.4247 - binary_accuracy: 0.7899 - val_loss: 0.4325 - val_binary_accuracy: 0.8382 - 3s/epoch - 348ms/step
# Epoch 43/150
# 9/9 - 3s - loss: 0.4232 - binary_accuracy: 0.8297 - val_loss: 0.4557 - val_binary_accuracy: 0.8235 - 3s/epoch - 349ms/step
# Epoch 44/150
# 9/9 - 3s - loss: 0.4105 - binary_accuracy: 0.8297 - val_loss: 0.4348 - val_binary_accuracy: 0.8235 - 3s/epoch - 345ms/step
# Epoch 45/150
# 9/9 - 3s - loss: 0.3620 - binary_accuracy: 0.8514 - val_loss: 0.4529 - val_binary_accuracy: 0.8235 - 3s/epoch - 340ms/step
# Epoch 46/150
# 9/9 - 3s - loss: 0.3781 - binary_accuracy: 0.8261 - val_loss: 0.4511 - val_binary_accuracy: 0.8382 - 3s/epoch - 350ms/step
# Epoch 47/150
# 9/9 - 3s - loss: 0.3685 - binary_accuracy: 0.8442 - val_loss: 0.4474 - val_binary_accuracy: 0.8382 - 3s/epoch - 365ms/step
# Epoch 48/150
# 9/9 - 3s - loss: 0.3828 - binary_accuracy: 0.8442 - val_loss: 0.4636 - val_binary_accuracy: 0.8088 - 3s/epoch - 361ms/step
# Epoch 49/150
# 9/9 - 3s - loss: 0.4031 - binary_accuracy: 0.7971 - val_loss: 0.4211 - val_binary_accuracy: 0.8235 - 3s/epoch - 349ms/step
# Epoch 50/150
# 9/9 - 3s - loss: 0.3832 - binary_accuracy: 0.8406 - val_loss: 0.4218 - val_binary_accuracy: 0.8382 - 3s/epoch - 355ms/step
# Epoch 51/150
# 9/9 - 3s - loss: 0.3918 - binary_accuracy: 0.8080 - val_loss: 0.4191 - val_binary_accuracy: 0.8382 - 3s/epoch - 354ms/step
# Epoch 52/150
# 9/9 - 3s - loss: 0.4322 - binary_accuracy: 0.8043 - val_loss: 0.4204 - val_binary_accuracy: 0.8235 - 3s/epoch - 349ms/step
# Epoch 53/150
# 9/9 - 3s - loss: 0.3747 - binary_accuracy: 0.8551 - val_loss: 0.4440 - val_binary_accuracy: 0.8382 - 3s/epoch - 361ms/step
# Epoch 54/150
# 9/9 - 3s - loss: 0.3774 - binary_accuracy: 0.8478 - val_loss: 0.4526 - val_binary_accuracy: 0.8382 - 3s/epoch - 358ms/step
# Epoch 55/150
# 9/9 - 3s - loss: 0.3937 - binary_accuracy: 0.8370 - val_loss: 0.4074 - val_binary_accuracy: 0.8382 - 3s/epoch - 355ms/step
# Epoch 56/150
# 9/9 - 3s - loss: 0.3206 - binary_accuracy: 0.8551 - val_loss: 0.4105 - val_binary_accuracy: 0.8382 - 3s/epoch - 338ms/step
# Epoch 57/150
# 9/9 - 3s - loss: 0.3998 - binary_accuracy: 0.8152 - val_loss: 0.4414 - val_binary_accuracy: 0.8382 - 3s/epoch - 348ms/step
# Epoch 58/150
# 9/9 - 3s - loss: 0.3570 - binary_accuracy: 0.8551 - val_loss: 0.4114 - val_binary_accuracy: 0.8382 - 3s/epoch - 337ms/step
# Epoch 59/150
# 9/9 - 3s - loss: 0.3794 - binary_accuracy: 0.8188 - val_loss: 0.4059 - val_binary_accuracy: 0.8382 - 3s/epoch - 350ms/step
# Epoch 60/150
# 9/9 - 3s - loss: 0.3935 - binary_accuracy: 0.8080 - val_loss: 0.4057 - val_binary_accuracy: 0.8382 - 3s/epoch - 348ms/step
# Epoch 61/150
# 9/9 - 3s - loss: 0.4135 - binary_accuracy: 0.8261 - val_loss: 0.4299 - val_binary_accuracy: 0.8382 - 3s/epoch - 349ms/step
# Epoch 62/150
# 9/9 - 3s - loss: 0.3065 - binary_accuracy: 0.8804 - val_loss: 0.4100 - val_binary_accuracy: 0.8382 - 3s/epoch - 348ms/step
# Epoch 63/150
# 9/9 - 3s - loss: 0.3431 - binary_accuracy: 0.8623 - val_loss: 0.4476 - val_binary_accuracy: 0.8382 - 3s/epoch - 350ms/step
# Epoch 64/150
# 9/9 - 3s - loss: 0.3475 - binary_accuracy: 0.8768 - val_loss: 0.4077 - val_binary_accuracy: 0.8382 - 3s/epoch - 338ms/step
# Epoch 65/150
# 9/9 - 3s - loss: 0.3122 - binary_accuracy: 0.8514 - val_loss: 0.3964 - val_binary_accuracy: 0.8382 - 3s/epoch - 340ms/step
# Epoch 66/150
# 9/9 - 3s - loss: 0.2897 - binary_accuracy: 0.8841 - val_loss: 0.3974 - val_binary_accuracy: 0.8382 - 3s/epoch - 353ms/step
# Epoch 67/150
# 9/9 - 3s - loss: 0.3288 - binary_accuracy: 0.8768 - val_loss: 0.4011 - val_binary_accuracy: 0.8382 - 3s/epoch - 343ms/step
# Epoch 68/150
# 9/9 - 3s - loss: 0.2815 - binary_accuracy: 0.8986 - val_loss: 0.4096 - val_binary_accuracy: 0.8382 - 3s/epoch - 355ms/step
# Epoch 69/150
# 9/9 - 3s - loss: 0.2899 - binary_accuracy: 0.8768 - val_loss: 0.3912 - val_binary_accuracy: 0.8382 - 3s/epoch - 353ms/step
# Epoch 70/150
# 9/9 - 3s - loss: 0.3466 - binary_accuracy: 0.8514 - val_loss: 0.3943 - val_binary_accuracy: 0.8382 - 3s/epoch - 367ms/step
# Epoch 71/150
# 9/9 - 3s - loss: 0.3396 - binary_accuracy: 0.8333 - val_loss: 0.3901 - val_binary_accuracy: 0.8382 - 3s/epoch - 356ms/step
# Epoch 72/150
# 9/9 - 3s - loss: 0.3213 - binary_accuracy: 0.8587 - val_loss: 0.4249 - val_binary_accuracy: 0.8382 - 3s/epoch - 352ms/step
# Epoch 73/150
# 9/9 - 3s - loss: 0.3921 - binary_accuracy: 0.8478 - val_loss: 0.4488 - val_binary_accuracy: 0.8382 - 3s/epoch - 345ms/step
# Epoch 74/150
# 9/9 - 3s - loss: 0.3355 - binary_accuracy: 0.8587 - val_loss: 0.3951 - val_binary_accuracy: 0.8382 - 3s/epoch - 340ms/step
# Epoch 75/150
# 9/9 - 3s - loss: 0.2884 - binary_accuracy: 0.8877 - val_loss: 0.3913 - val_binary_accuracy: 0.8382 - 3s/epoch - 355ms/step
# Epoch 76/150
# 9/9 - 3s - loss: 0.3121 - binary_accuracy: 0.8696 - val_loss: 0.3947 - val_binary_accuracy: 0.8382 - 3s/epoch - 352ms/step
# Epoch 77/150
# 9/9 - 3s - loss: 0.3364 - binary_accuracy: 0.8442 - val_loss: 0.3956 - val_binary_accuracy: 0.8382 - 3s/epoch - 353ms/step
# Epoch 78/150
# 9/9 - 3s - loss: 0.3497 - binary_accuracy: 0.8514 - val_loss: 0.4317 - val_binary_accuracy: 0.8382 - 3s/epoch - 351ms/step
# Epoch 79/150
# 9/9 - 3s - loss: 0.3351 - binary_accuracy: 0.8478 - val_loss: 0.3908 - val_binary_accuracy: 0.8382 - 3s/epoch - 356ms/step
# Epoch 80/150
# 9/9 - 4s - loss: 0.3327 - binary_accuracy: 0.8768 - val_loss: 0.3979 - val_binary_accuracy: 0.8529 - 4s/epoch - 426ms/step
# Epoch 81/150
# 9/9 - 3s - loss: 0.3028 - binary_accuracy: 0.8587 - val_loss: 0.3840 - val_binary_accuracy: 0.8382 - 3s/epoch - 353ms/step
# Epoch 82/150
# 9/9 - 3s - loss: 0.2922 - binary_accuracy: 0.8841 - val_loss: 0.3883 - val_binary_accuracy: 0.8382 - 3s/epoch - 338ms/step
# Epoch 83/150
# 9/9 - 3s - loss: 0.3061 - binary_accuracy: 0.8986 - val_loss: 0.3869 - val_binary_accuracy: 0.8382 - 3s/epoch - 355ms/step
# Epoch 84/150
# 9/9 - 4s - loss: 0.2954 - binary_accuracy: 0.8841 - val_loss: 0.3903 - val_binary_accuracy: 0.8676 - 4s/epoch - 486ms/step
# Epoch 85/150
# 9/9 - 3s - loss: 0.3387 - binary_accuracy: 0.8478 - val_loss: 0.3982 - val_binary_accuracy: 0.8529 - 3s/epoch - 344ms/step
# Epoch 86/150
# 9/9 - 3s - loss: 0.3442 - binary_accuracy: 0.8297 - val_loss: 0.3761 - val_binary_accuracy: 0.8382 - 3s/epoch - 339ms/step
# Epoch 87/150
# 9/9 - 3s - loss: 0.3525 - binary_accuracy: 0.8406 - val_loss: 0.3729 - val_binary_accuracy: 0.8382 - 3s/epoch - 369ms/step
# Epoch 88/150
# 9/9 - 3s - loss: 0.2897 - binary_accuracy: 0.8514 - val_loss: 0.3924 - val_binary_accuracy: 0.8529 - 3s/epoch - 347ms/step
# Epoch 89/150
# 9/9 - 3s - loss: 0.2946 - binary_accuracy: 0.8804 - val_loss: 0.3987 - val_binary_accuracy: 0.8382 - 3s/epoch - 346ms/step
# Epoch 90/150
# 9/9 - 3s - loss: 0.3119 - binary_accuracy: 0.8696 - val_loss: 0.3731 - val_binary_accuracy: 0.8382 - 3s/epoch - 352ms/step
# Epoch 91/150
# 9/9 - 3s - loss: 0.3299 - binary_accuracy: 0.8696 - val_loss: 0.3729 - val_binary_accuracy: 0.8382 - 3s/epoch - 344ms/step
# Epoch 92/150
# 9/9 - 3s - loss: 0.3274 - binary_accuracy: 0.8696 - val_loss: 0.3712 - val_binary_accuracy: 0.8382 - 3s/epoch - 353ms/step
# Epoch 93/150
# 9/9 - 3s - loss: 0.3392 - binary_accuracy: 0.8406 - val_loss: 0.3645 - val_binary_accuracy: 0.8382 - 3s/epoch - 346ms/step
# Epoch 94/150
# 9/9 - 3s - loss: 0.3082 - binary_accuracy: 0.8696 - val_loss: 0.3781 - val_binary_accuracy: 0.8676 - 3s/epoch - 347ms/step
# Epoch 95/150
# 9/9 - 3s - loss: 0.2802 - binary_accuracy: 0.8949 - val_loss: 0.3809 - val_binary_accuracy: 0.8676 - 3s/epoch - 347ms/step
# Epoch 96/150
# 9/9 - 3s - loss: 0.3329 - binary_accuracy: 0.8514 - val_loss: 0.3916 - val_binary_accuracy: 0.8382 - 3s/epoch - 342ms/step
# Epoch 97/150
# 9/9 - 3s - loss: 0.3022 - binary_accuracy: 0.8949 - val_loss: 0.3593 - val_binary_accuracy: 0.8382 - 3s/epoch - 342ms/step
# Epoch 98/150
# 9/9 - 3s - loss: 0.3630 - binary_accuracy: 0.8261 - val_loss: 0.3791 - val_binary_accuracy: 0.8529 - 3s/epoch - 349ms/step
# Epoch 99/150
# 9/9 - 3s - loss: 0.3275 - binary_accuracy: 0.8768 - val_loss: 0.3637 - val_binary_accuracy: 0.8529 - 3s/epoch - 351ms/step
# Epoch 100/150
# 9/9 - 3s - loss: 0.3204 - binary_accuracy: 0.8659 - val_loss: 0.3584 - val_binary_accuracy: 0.8382 - 3s/epoch - 343ms/step
# Epoch 101/150
# 9/9 - 3s - loss: 0.3065 - binary_accuracy: 0.8732 - val_loss: 0.3640 - val_binary_accuracy: 0.8676 - 3s/epoch - 351ms/step
# Epoch 102/150
# 9/9 - 3s - loss: 0.3231 - binary_accuracy: 0.8732 - val_loss: 0.3928 - val_binary_accuracy: 0.8382 - 3s/epoch - 355ms/step
# Epoch 103/150
# 9/9 - 3s - loss: 0.3291 - binary_accuracy: 0.8841 - val_loss: 0.3590 - val_binary_accuracy: 0.8382 - 3s/epoch - 351ms/step
# Epoch 104/150
# 9/9 - 3s - loss: 0.2832 - binary_accuracy: 0.9022 - val_loss: 0.3707 - val_binary_accuracy: 0.8676 - 3s/epoch - 345ms/step
# Epoch 105/150
# 9/9 - 3s - loss: 0.2700 - binary_accuracy: 0.8732 - val_loss: 0.3659 - val_binary_accuracy: 0.8676 - 3s/epoch - 353ms/step
# Epoch 106/150
# 9/9 - 3s - loss: 0.3560 - binary_accuracy: 0.8261 - val_loss: 0.3537 - val_binary_accuracy: 0.8529 - 3s/epoch - 357ms/step
# Epoch 107/150
# 9/9 - 3s - loss: 0.3215 - binary_accuracy: 0.8732 - val_loss: 0.3565 - val_binary_accuracy: 0.8382 - 3s/epoch - 342ms/step
# Epoch 108/150
# 9/9 - 3s - loss: 0.2471 - binary_accuracy: 0.9094 - val_loss: 0.3624 - val_binary_accuracy: 0.8676 - 3s/epoch - 347ms/step
# Epoch 109/150
# 9/9 - 3s - loss: 0.2867 - binary_accuracy: 0.8551 - val_loss: 0.3705 - val_binary_accuracy: 0.8676 - 3s/epoch - 340ms/step
# Epoch 110/150
# 9/9 - 3s - loss: 0.3231 - binary_accuracy: 0.8370 - val_loss: 0.3583 - val_binary_accuracy: 0.8529 - 3s/epoch - 343ms/step
# Epoch 111/150
# 9/9 - 3s - loss: 0.3352 - binary_accuracy: 0.8768 - val_loss: 0.3967 - val_binary_accuracy: 0.8382 - 3s/epoch - 346ms/step
# Epoch 112/150
# 9/9 - 3s - loss: 0.2917 - binary_accuracy: 0.8768 - val_loss: 0.3608 - val_binary_accuracy: 0.8676 - 3s/epoch - 345ms/step
# Epoch 113/150
# 9/9 - 3s - loss: 0.3131 - binary_accuracy: 0.8696 - val_loss: 0.3522 - val_binary_accuracy: 0.8382 - 3s/epoch - 348ms/step
# Epoch 114/150
# 9/9 - 3s - loss: 0.3035 - binary_accuracy: 0.8804 - val_loss: 0.3511 - val_binary_accuracy: 0.8382 - 3s/epoch - 357ms/step
# Epoch 115/150
# 9/9 - 3s - loss: 0.3184 - binary_accuracy: 0.8841 - val_loss: 0.3580 - val_binary_accuracy: 0.8676 - 3s/epoch - 351ms/step
# Epoch 116/150
# 9/9 - 3s - loss: 0.2852 - binary_accuracy: 0.8877 - val_loss: 0.3598 - val_binary_accuracy: 0.8676 - 3s/epoch - 353ms/step
# Epoch 117/150
# 9/9 - 3s - loss: 0.3062 - binary_accuracy: 0.8877 - val_loss: 0.3520 - val_binary_accuracy: 0.8529 - 3s/epoch - 363ms/step
# Epoch 118/150
# 9/9 - 3s - loss: 0.3296 - binary_accuracy: 0.8623 - val_loss: 0.3577 - val_binary_accuracy: 0.8676 - 3s/epoch - 351ms/step
# Epoch 119/150
# 9/9 - 3s - loss: 0.2776 - binary_accuracy: 0.8949 - val_loss: 0.3666 - val_binary_accuracy: 0.8529 - 3s/epoch - 355ms/step
# Epoch 120/150
# 9/9 - 3s - loss: 0.3101 - binary_accuracy: 0.8623 - val_loss: 0.3617 - val_binary_accuracy: 0.8676 - 3s/epoch - 352ms/step
# Epoch 121/150
# 9/9 - 3s - loss: 0.3085 - binary_accuracy: 0.8659 - val_loss: 0.3449 - val_binary_accuracy: 0.8529 - 3s/epoch - 343ms/step
# Epoch 122/150
# 9/9 - 3s - loss: 0.3204 - binary_accuracy: 0.8514 - val_loss: 0.3453 - val_binary_accuracy: 0.8676 - 3s/epoch - 349ms/step
# Epoch 123/150
# 9/9 - 3s - loss: 0.2839 - binary_accuracy: 0.8877 - val_loss: 0.3552 - val_binary_accuracy: 0.8676 - 3s/epoch - 351ms/step
# Epoch 124/150
# 9/9 - 3s - loss: 0.3187 - binary_accuracy: 0.8478 - val_loss: 0.3504 - val_binary_accuracy: 0.8676 - 3s/epoch - 345ms/step
# Epoch 125/150
# 9/9 - 3s - loss: 0.2780 - binary_accuracy: 0.9058 - val_loss: 0.3581 - val_binary_accuracy: 0.8529 - 3s/epoch - 353ms/step
# Epoch 126/150
# 9/9 - 3s - loss: 0.2588 - binary_accuracy: 0.8804 - val_loss: 0.3572 - val_binary_accuracy: 0.8529 - 3s/epoch - 346ms/step
# Epoch 127/150
# 9/9 - 3s - loss: 0.2961 - binary_accuracy: 0.8623 - val_loss: 0.3423 - val_binary_accuracy: 0.8676 - 3s/epoch - 347ms/step
# Epoch 128/150
# 9/9 - 3s - loss: 0.2991 - binary_accuracy: 0.8514 - val_loss: 0.3498 - val_binary_accuracy: 0.8676 - 3s/epoch - 345ms/step
# Epoch 129/150
# 9/9 - 3s - loss: 0.2491 - binary_accuracy: 0.9058 - val_loss: 0.3458 - val_binary_accuracy: 0.8676 - 3s/epoch - 352ms/step
# Epoch 130/150
# 9/9 - 3s - loss: 0.3013 - binary_accuracy: 0.8732 - val_loss: 0.3542 - val_binary_accuracy: 0.8676 - 3s/epoch - 347ms/step
# Epoch 131/150
# 9/9 - 3s - loss: 0.3096 - binary_accuracy: 0.8623 - val_loss: 0.3846 - val_binary_accuracy: 0.8382 - 3s/epoch - 352ms/step
# Epoch 132/150
# 9/9 - 3s - loss: 0.3144 - binary_accuracy: 0.8696 - val_loss: 0.3384 - val_binary_accuracy: 0.8676 - 3s/epoch - 357ms/step
# Epoch 133/150
# 9/9 - 3s - loss: 0.2644 - binary_accuracy: 0.8949 - val_loss: 0.3452 - val_binary_accuracy: 0.8676 - 3s/epoch - 352ms/step
# Epoch 134/150
# 9/9 - 3s - loss: 0.2907 - binary_accuracy: 0.8696 - val_loss: 0.3432 - val_binary_accuracy: 0.8676 - 3s/epoch - 379ms/step
# Epoch 135/150
# 9/9 - 3s - loss: 0.3149 - binary_accuracy: 0.8768 - val_loss: 0.3565 - val_binary_accuracy: 0.8676 - 3s/epoch - 352ms/step
# Epoch 136/150
# 9/9 - 3s - loss: 0.3032 - binary_accuracy: 0.8768 - val_loss: 0.3562 - val_binary_accuracy: 0.8529 - 3s/epoch - 340ms/step
# Epoch 137/150
# 9/9 - 3s - loss: 0.2857 - binary_accuracy: 0.8841 - val_loss: 0.3576 - val_binary_accuracy: 0.8529 - 3s/epoch - 345ms/step
# Epoch 138/150
# 9/9 - 3s - loss: 0.2680 - binary_accuracy: 0.9022 - val_loss: 0.3473 - val_binary_accuracy: 0.8676 - 3s/epoch - 338ms/step
# Epoch 139/150
# 9/9 - 3s - loss: 0.2817 - binary_accuracy: 0.8913 - val_loss: 0.3539 - val_binary_accuracy: 0.8529 - 3s/epoch - 340ms/step
# Epoch 140/150
# 9/9 - 4s - loss: 0.2474 - binary_accuracy: 0.8986 - val_loss: 0.3372 - val_binary_accuracy: 0.8824 - 4s/epoch - 483ms/step
# Epoch 141/150
# 9/9 - 3s - loss: 0.2865 - binary_accuracy: 0.8659 - val_loss: 0.3343 - val_binary_accuracy: 0.8824 - 3s/epoch - 338ms/step
# Epoch 142/150
# 9/9 - 3s - loss: 0.2743 - binary_accuracy: 0.8659 - val_loss: 0.3398 - val_binary_accuracy: 0.8676 - 3s/epoch - 340ms/step
# Epoch 143/150
# 9/9 - 3s - loss: 0.2971 - binary_accuracy: 0.8587 - val_loss: 0.3730 - val_binary_accuracy: 0.8529 - 3s/epoch - 339ms/step
# Epoch 144/150
# 9/9 - 3s - loss: 0.2872 - binary_accuracy: 0.8949 - val_loss: 0.3597 - val_binary_accuracy: 0.8529 - 3s/epoch - 336ms/step
# Epoch 145/150
# 9/9 - 3s - loss: 0.2989 - binary_accuracy: 0.8659 - val_loss: 0.3392 - val_binary_accuracy: 0.8676 - 3s/epoch - 332ms/step
# Epoch 146/150
# 9/9 - 3s - loss: 0.2228 - binary_accuracy: 0.9203 - val_loss: 0.3503 - val_binary_accuracy: 0.8676 - 3s/epoch - 341ms/step
# Epoch 147/150
# 9/9 - 3s - loss: 0.2602 - binary_accuracy: 0.8949 - val_loss: 0.3475 - val_binary_accuracy: 0.8676 - 3s/epoch - 340ms/step
# Epoch 148/150
# 9/9 - 3s - loss: 0.2853 - binary_accuracy: 0.8949 - val_loss: 0.3376 - val_binary_accuracy: 0.8824 - 3s/epoch - 335ms/step
# Epoch 149/150
# 9/9 - 3s - loss: 0.2726 - binary_accuracy: 0.8986 - val_loss: 0.3525 - val_binary_accuracy: 0.8529 - 3s/epoch - 343ms/step
# Epoch 150/150
# 9/9 - 3s - loss: 0.2331 - binary_accuracy: 0.9022 - val_loss: 0.3393 - val_binary_accuracy: 0.8676 - 3s/epoch - 339ms/step

# %%
#accuracy
plt.plot(result.history['binary_accuracy'])
plt.plot(result.history['val_binary_accuracy'])
# plt.plot(result.history['accuracy'])
# plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# OPTIONAL: Decide if best weights should be loaded from previous model based on val_acc
# The model weights (that are considered the best) are loaded into the model.
result = model.load_weights(checkpoint_filepath)

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model
model.save("Models/ResNet50/ResNet50_covid_classification.h5")

os.chdir(destination)

# %% [markdown]
# <h3>Evaluate Test data</h3>

# %%
print(sum(cb.logs) / 150)

testLoss, testAcc = model.evaluate(test)
print('''
Test Loss: {}
Test Accuracy: {}
'''.format(testLoss, testAcc))
# Out:
# 3.343142608000065
# 3/3 [==============================] - 1s 495ms/step - loss: 0.3823 - binary_accuracy: 0.8140
#
# Test Loss: 0.38233938813209534
# Test Accuracy: 0.8139534592628479

# %% [markdown]
# <h4>*Optional - Fine tune model with two-step training*</h4>

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

mobile.trainable = True

for layer in mobile.layers[:-2]:
    layer.trainable = False
    
#re-train the model at a very low learning rate
model.compile(optimizer=Adam(learning_rate=0.00006), loss='binary_crossentropy', metrics=['binary_accuracy'])

result = model.fit(x=train, validation_data=validation, epochs=100, verbose=2, callbacks=[cb, es])
# Out:
# Epoch 1/100
# 9/9 - 7s - loss: 0.2694 - binary_accuracy: 0.8804 - val_loss: 0.3406 - val_binary_accuracy: 0.8676 - 7s/epoch - 749ms/step
# Epoch 2/100
# 9/9 - 3s - loss: 0.2648 - binary_accuracy: 0.8913 - val_loss: 0.3468 - val_binary_accuracy: 0.8676 - 3s/epoch - 348ms/step
# Epoch 3/100
# 9/9 - 3s - loss: 0.2718 - binary_accuracy: 0.8949 - val_loss: 0.3444 - val_binary_accuracy: 0.8676 - 3s/epoch - 335ms/step
# Epoch 4/100
# 9/9 - 3s - loss: 0.2525 - binary_accuracy: 0.8768 - val_loss: 0.3464 - val_binary_accuracy: 0.8676 - 3s/epoch - 351ms/step
# Epoch 5/100
# 9/9 - 3s - loss: 0.2302 - binary_accuracy: 0.9130 - val_loss: 0.3457 - val_binary_accuracy: 0.8676 - 3s/epoch - 347ms/step
# Epoch 6/100
# 9/9 - 3s - loss: 0.2828 - binary_accuracy: 0.8732 - val_loss: 0.3492 - val_binary_accuracy: 0.8529 - 3s/epoch - 339ms/step
# Epoch 7/100
# 9/9 - 3s - loss: 0.2699 - binary_accuracy: 0.8877 - val_loss: 0.3495 - val_binary_accuracy: 0.8529 - 3s/epoch - 345ms/step
# Epoch 8/100
# 9/9 - 3s - loss: 0.2852 - binary_accuracy: 0.8913 - val_loss: 0.3446 - val_binary_accuracy: 0.8676 - 3s/epoch - 338ms/step
# Epoch 9/100
# 9/9 - 3s - loss: 0.2619 - binary_accuracy: 0.8949 - val_loss: 0.3446 - val_binary_accuracy: 0.8676 - 3s/epoch - 327ms/step
# Epoch 10/100
# 9/9 - 3s - loss: 0.2457 - binary_accuracy: 0.8841 - val_loss: 0.3465 - val_binary_accuracy: 0.8676 - 3s/epoch - 335ms/step
# Epoch 11/100
# 9/9 - 3s - loss: 0.2310 - binary_accuracy: 0.8913 - val_loss: 0.3492 - val_binary_accuracy: 0.8529 - 3s/epoch - 327ms/step
# Epoch 11: early stopping

# %% [markdown]
# <h3>Accuracy and Loss graph</h3>

# %%
#accuracy
plt.plot(result.history['binary_accuracy'])
plt.plot(result.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# <h3>Classification report</h3>

# %%
predictions = model.predict(test, verbose=0)
# predictions = predictions.reshape(1,-1)[0]
# lst = np.argmax(predictions, axis= 1)
lst = (predictions > 0.5).astype(int)

print(classification_report(test.classes, lst, target_names = test.class_indices))
# Out:
#               precision    recall  f1-score   support
#
#        covid       0.85      0.78      0.81        36
#       normal       0.85      0.90      0.87        50
#
#     accuracy                           0.85        86
#    macro avg       0.85      0.84      0.84        86
# weighted avg       0.85      0.85      0.85        86

# %% [markdown]
# <h3>Confusion matrix</h3>

# %%
result = confusion_matrix(test.classes, lst)
print(result)

def plot_confusion_matrix(result, classes, cmap=plt.cm.Blues):
    plt.subplots(figsize=(7, 7))
    plt.imshow(result, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

    thresh = result.max() / 2.
    for i, j in itertools.product(range(result.shape[0]), range(result.shape[1])):
        plt.text(j, i, result[i, j],
            horizontalalignment="center",
            color = "white" if result[i, j] > thresh else "black")
        
    #current matplotlib version will cut off top and bottom of the matrix, 
    #hence the manual workaround - remove if matplotlib version does not cut off
    b, t = plt.ylim() # discover bottom and top values
    b += 0.5 # Add 0.5 to bottom
    t -= 0.5 # Subtract 0.5 from top
    plt.ylim(b, t) # update ylim(bottom, top) values
    plt.show()
    
plot_confusion_matrix(result, list(test.class_indices.keys()))
# Out:
# [[28  8]
#  [ 5 45]]

# %% [markdown]
# <h3>Save the model</h3>

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model
model.save("Models/ResNet50/ResNet50_covid_classification_finetuned.h5")
