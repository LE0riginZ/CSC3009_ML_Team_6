# %% [markdown]
# <h3>Import packages</h3>

# %%
from datetime import date
from timeit import default_timer as timer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
# from keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import imagenet_utils
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Configure TensorFlow to use GPU for training
tf.config.list_physical_devices('GPU') 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_physical_devices('GPU')
#Set GPU memory limit so my GPU doesn't crash
if gpus:
    try:
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <h3>Create class to record time taken to train the model</h3>

# %%
#class to record time taken to train per epoch
class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

# %% [markdown]
# <h3>Create train and test folder</h3>

# %%
#creates a folder each time the set of code is run to sort dataset into train and test
day = date.today()
formatDate = day.strftime("%b-%d-%Y")

#create folder with current date to group predictions ran in a day together, if it does not exists
if os.path.isdir('Prediction (' + formatDate + ')') is False:
    folder = os.mkdir('Prediction (' + formatDate + ')')
folder = 'Prediction (' + formatDate + ')'

#looping through to find if destination folder exists
i = 1
while True:
    if os.path.isdir(folder + '/dataset_6 - ' + str(i)) is False:
        break
    i += 1

#destination path for unsorted folder
destination = folder + '/dataset_6 - ' + str(i)

#source path for unsorted folder
source = 'dataset_6/'

#duplicate the unsorted folder from source to destination
shutil.copytree(source, destination)

os.mkdir(destination + '/train')
os.mkdir(destination + '/test')

# %% [markdown]
# <h3>Sort dataset into train and test folder</h3>

# %%
#function to split images into training (80%) and testing (20%) and return both
def split(data):
    num = int(len(data) * 0.8)
    # num = int(len(data) * 0.9) #90/10 split
#     num = int(len(data) * 0.7) #70/30 split
    random.shuffle(data)
    return data[:num], data[num:]

dir = os.chdir(destination)
for category in os.listdir(dir):
    #skip the iteration if folder is "train" or "test"
    skip = ['train', 'test']
    if category in skip:
        continue
    
    shutil.move(f'{category}', 'train')
    #create a subfolder with the same name in test
    os.mkdir(f'test/{category}')

    #get the images in each folder (battery type) for spltting of data into training and testing
    img = os.listdir(f'train/{category}')
    training, testing = split(img)
    
    for file in testing:
        shutil.move(f'train/{category}/{file}', f'test/{category}')

# %% [markdown]
# <h3>Transfer Learning</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.VGG19(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %%
mobile.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in mobile.layers[:-2]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))
x = mobile(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(1, activation="sigmoid")(x)  

model = keras.Model(inputs, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 20,024,897
# Trainable params: 2,360,321
# Non-trainable params: 17,664,576
# _________________________________________________________________

# %% [markdown]
# <h3>Process data</h3>

# %%
train_path = 'train'
test_path = 'test'

#for data augmentation on training data
datagen = ImageDataGenerator( 
    preprocessing_function =tf.keras.applications.resnet50.preprocess_input,
    validation_split=0.2,
    # validation_split=0.1, #changes made for 90/10 split
    rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.2, # Randomly zoom image 
    width_shift_range = 0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range = 0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip = True,  # randomly flip images
#     vertical_flip = False,    # randomly flip images
    vertical_flip = True, #include vertical flip for better generalisation
    )  

#takes images from directory path and generates batches of augmented data
train = datagen.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    class_mode = 'binary',
    batch_size=32,
    subset='training',
        shuffle = False)

#for validation data
validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input, 
                                        validation_split=0.2)
# validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
#                                         validation_split=0.1) #changes made for 90/10 split


validation = validation_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    class_mode = 'binary',
    batch_size=32,
    subset='validation',
        shuffle = False)

#for test data
test = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input)\
.flow_from_directory(directory=test_path, target_size=(224,224), class_mode = 'binary', batch_size=32, shuffle=False)
# Out:
# Found 276 images belonging to 2 classes.
# Found 68 images belonging to 2 classes.
# Found 86 images belonging to 2 classes.

# %% [markdown]
# <h3>Train model</h3>

# %%
model.compile(optimizer=Adam(learning_rate=0.0006), loss='binary_crossentropy', metrics=['binary_accuracy']) #Last best setting
# model.compile(optimizer=Adam(learning_rate=0.006), loss='binary_crossentropy', metrics=['accuracy']) #Last best setting
checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_binary_accuracy',
    # monitor='val_accuracy',
    mode='max',
    save_best_only=True) #save best model

#more epochs for better results
result = model.fit(x=train, validation_data=validation, epochs=150, verbose=2, callbacks=[model_checkpoint_callback,cb])
# Out:
# Epoch 1/150
# 9/9 - 18s - loss: 12.5437 - binary_accuracy: 0.5145 - val_loss: 4.1413 - val_binary_accuracy: 0.5882 - 18s/epoch - 2s/step
# Epoch 2/150
# 9/9 - 3s - loss: 1.1757 - binary_accuracy: 0.6413 - val_loss: 0.6397 - val_binary_accuracy: 0.5882 - 3s/epoch - 367ms/step
# Epoch 3/150
# 9/9 - 4s - loss: 0.5845 - binary_accuracy: 0.6884 - val_loss: 0.6183 - val_binary_accuracy: 0.7206 - 4s/epoch - 391ms/step
# Epoch 4/150
# 9/9 - 3s - loss: 0.6303 - binary_accuracy: 0.6341 - val_loss: 0.5039 - val_binary_accuracy: 0.6471 - 3s/epoch - 349ms/step
# Epoch 5/150
# 9/9 - 3s - loss: 0.5842 - binary_accuracy: 0.6558 - val_loss: 0.5236 - val_binary_accuracy: 0.7206 - 3s/epoch - 343ms/step
# Epoch 6/150
# 9/9 - 3s - loss: 0.5214 - binary_accuracy: 0.7283 - val_loss: 0.5218 - val_binary_accuracy: 0.7206 - 3s/epoch - 345ms/step
# Epoch 7/150
# 9/9 - 3s - loss: 0.5079 - binary_accuracy: 0.7609 - val_loss: 0.5157 - val_binary_accuracy: 0.7206 - 3s/epoch - 343ms/step
# Epoch 8/150
# 9/9 - 3s - loss: 0.4705 - binary_accuracy: 0.7572 - val_loss: 0.4477 - val_binary_accuracy: 0.7647 - 3s/epoch - 388ms/step
# Epoch 9/150
# 9/9 - 3s - loss: 0.4673 - binary_accuracy: 0.7790 - val_loss: 0.4442 - val_binary_accuracy: 0.7647 - 3s/epoch - 351ms/step
# Epoch 10/150
# 9/9 - 4s - loss: 0.4131 - binary_accuracy: 0.7899 - val_loss: 0.3674 - val_binary_accuracy: 0.8676 - 4s/epoch - 419ms/step
# Epoch 11/150
# 9/9 - 3s - loss: 0.4914 - binary_accuracy: 0.7645 - val_loss: 0.4091 - val_binary_accuracy: 0.7941 - 3s/epoch - 356ms/step
# Epoch 12/150
# 9/9 - 3s - loss: 0.4314 - binary_accuracy: 0.7899 - val_loss: 0.4190 - val_binary_accuracy: 0.8235 - 3s/epoch - 343ms/step
# Epoch 13/150
# 9/9 - 3s - loss: 0.3443 - binary_accuracy: 0.8514 - val_loss: 0.4017 - val_binary_accuracy: 0.8382 - 3s/epoch - 345ms/step
# Epoch 14/150
# 9/9 - 4s - loss: 0.3416 - binary_accuracy: 0.8514 - val_loss: 0.3556 - val_binary_accuracy: 0.8824 - 4s/epoch - 401ms/step
# Epoch 15/150
# 9/9 - 3s - loss: 0.4090 - binary_accuracy: 0.8406 - val_loss: 0.3025 - val_binary_accuracy: 0.8824 - 3s/epoch - 352ms/step
# Epoch 16/150
# 9/9 - 3s - loss: 0.3342 - binary_accuracy: 0.8551 - val_loss: 0.6423 - val_binary_accuracy: 0.7794 - 3s/epoch - 350ms/step
# Epoch 17/150
# 9/9 - 3s - loss: 0.9706 - binary_accuracy: 0.7391 - val_loss: 0.3382 - val_binary_accuracy: 0.8529 - 3s/epoch - 350ms/step
# Epoch 18/150
# 9/9 - 3s - loss: 0.4059 - binary_accuracy: 0.8116 - val_loss: 0.2826 - val_binary_accuracy: 0.8676 - 3s/epoch - 352ms/step
# Epoch 19/150
# 9/9 - 3s - loss: 0.4792 - binary_accuracy: 0.8007 - val_loss: 0.3315 - val_binary_accuracy: 0.8235 - 3s/epoch - 370ms/step
# Epoch 20/150
# 9/9 - 3s - loss: 0.3968 - binary_accuracy: 0.8261 - val_loss: 0.3467 - val_binary_accuracy: 0.8676 - 3s/epoch - 373ms/step
# Epoch 21/150
# 9/9 - 4s - loss: 0.3097 - binary_accuracy: 0.8804 - val_loss: 0.3296 - val_binary_accuracy: 0.8676 - 4s/epoch - 391ms/step
# Epoch 22/150
# 9/9 - 3s - loss: 0.3270 - binary_accuracy: 0.8406 - val_loss: 0.3140 - val_binary_accuracy: 0.8382 - 3s/epoch - 378ms/step
# Epoch 23/150
# 9/9 - 4s - loss: 0.3850 - binary_accuracy: 0.8152 - val_loss: 0.3554 - val_binary_accuracy: 0.8088 - 4s/epoch - 390ms/step
# Epoch 24/150
# 9/9 - 3s - loss: 0.3635 - binary_accuracy: 0.8370 - val_loss: 0.3064 - val_binary_accuracy: 0.8824 - 3s/epoch - 338ms/step
# Epoch 25/150
# 9/9 - 3s - loss: 0.3206 - binary_accuracy: 0.8732 - val_loss: 0.3889 - val_binary_accuracy: 0.8235 - 3s/epoch - 337ms/step
# Epoch 26/150
# 9/9 - 3s - loss: 0.2863 - binary_accuracy: 0.8659 - val_loss: 0.2942 - val_binary_accuracy: 0.8676 - 3s/epoch - 339ms/step
# Epoch 27/150
# 9/9 - 3s - loss: 0.2751 - binary_accuracy: 0.8913 - val_loss: 0.2949 - val_binary_accuracy: 0.8529 - 3s/epoch - 343ms/step
# Epoch 28/150
# 9/9 - 3s - loss: 0.2870 - binary_accuracy: 0.8986 - val_loss: 0.3210 - val_binary_accuracy: 0.8382 - 3s/epoch - 339ms/step
# Epoch 29/150
# 9/9 - 3s - loss: 0.2719 - binary_accuracy: 0.8804 - val_loss: 0.2528 - val_binary_accuracy: 0.9118 - 3s/epoch - 375ms/step
# Epoch 30/150
# 9/9 - 3s - loss: 0.2654 - binary_accuracy: 0.8913 - val_loss: 0.2236 - val_binary_accuracy: 0.9118 - 3s/epoch - 350ms/step
# Epoch 31/150
# 9/9 - 3s - loss: 0.3062 - binary_accuracy: 0.8587 - val_loss: 0.2588 - val_binary_accuracy: 0.8824 - 3s/epoch - 340ms/step
# Epoch 32/150
# 9/9 - 3s - loss: 0.2749 - binary_accuracy: 0.8877 - val_loss: 0.2962 - val_binary_accuracy: 0.8529 - 3s/epoch - 340ms/step
# Epoch 33/150
# 9/9 - 3s - loss: 0.2668 - binary_accuracy: 0.8913 - val_loss: 0.2659 - val_binary_accuracy: 0.8824 - 3s/epoch - 340ms/step
# Epoch 34/150
# 9/9 - 3s - loss: 0.2464 - binary_accuracy: 0.8913 - val_loss: 0.2850 - val_binary_accuracy: 0.8529 - 3s/epoch - 341ms/step
# Epoch 35/150
# 9/9 - 3s - loss: 0.2825 - binary_accuracy: 0.8514 - val_loss: 0.2907 - val_binary_accuracy: 0.8676 - 3s/epoch - 340ms/step
# Epoch 36/150
# 9/9 - 3s - loss: 0.2299 - binary_accuracy: 0.8949 - val_loss: 0.3158 - val_binary_accuracy: 0.8382 - 3s/epoch - 338ms/step
# Epoch 37/150
# 9/9 - 3s - loss: 0.2361 - binary_accuracy: 0.9022 - val_loss: 0.2771 - val_binary_accuracy: 0.8382 - 3s/epoch - 343ms/step
# Epoch 38/150
# 9/9 - 3s - loss: 0.3571 - binary_accuracy: 0.8225 - val_loss: 0.2994 - val_binary_accuracy: 0.8382 - 3s/epoch - 341ms/step
# Epoch 39/150
# 9/9 - 3s - loss: 0.4654 - binary_accuracy: 0.8152 - val_loss: 0.4306 - val_binary_accuracy: 0.7941 - 3s/epoch - 349ms/step
# Epoch 40/150
# 9/9 - 3s - loss: 0.2829 - binary_accuracy: 0.8877 - val_loss: 0.2915 - val_binary_accuracy: 0.9118 - 3s/epoch - 341ms/step
# Epoch 41/150
# 9/9 - 3s - loss: 0.2628 - binary_accuracy: 0.9022 - val_loss: 0.2910 - val_binary_accuracy: 0.8824 - 3s/epoch - 339ms/step
# Epoch 42/150
# 9/9 - 3s - loss: 0.2419 - binary_accuracy: 0.9167 - val_loss: 0.3578 - val_binary_accuracy: 0.8235 - 3s/epoch - 341ms/step
# Epoch 43/150
# 9/9 - 3s - loss: 0.4720 - binary_accuracy: 0.8297 - val_loss: 0.2861 - val_binary_accuracy: 0.8824 - 3s/epoch - 338ms/step
# Epoch 44/150
# 9/9 - 3s - loss: 0.2962 - binary_accuracy: 0.8659 - val_loss: 0.2776 - val_binary_accuracy: 0.8824 - 3s/epoch - 342ms/step
# Epoch 45/150
# 9/9 - 3s - loss: 0.2285 - binary_accuracy: 0.8949 - val_loss: 0.2702 - val_binary_accuracy: 0.8824 - 3s/epoch - 352ms/step
# Epoch 46/150
# 9/9 - 3s - loss: 0.2292 - binary_accuracy: 0.8986 - val_loss: 0.2617 - val_binary_accuracy: 0.8676 - 3s/epoch - 332ms/step
# Epoch 47/150
# 9/9 - 3s - loss: 0.2782 - binary_accuracy: 0.8768 - val_loss: 0.2954 - val_binary_accuracy: 0.8382 - 3s/epoch - 334ms/step
# Epoch 48/150
# 9/9 - 3s - loss: 0.2000 - binary_accuracy: 0.9275 - val_loss: 0.2497 - val_binary_accuracy: 0.9118 - 3s/epoch - 333ms/step
# Epoch 49/150
# 9/9 - 3s - loss: 0.1886 - binary_accuracy: 0.9457 - val_loss: 0.2607 - val_binary_accuracy: 0.9118 - 3s/epoch - 331ms/step
# Epoch 50/150
# 9/9 - 3s - loss: 0.1898 - binary_accuracy: 0.9203 - val_loss: 0.2749 - val_binary_accuracy: 0.8971 - 3s/epoch - 336ms/step
# Epoch 51/150
# 9/9 - 3s - loss: 0.2417 - binary_accuracy: 0.8986 - val_loss: 0.3698 - val_binary_accuracy: 0.8382 - 3s/epoch - 352ms/step
# Epoch 52/150
# 9/9 - 3s - loss: 0.1608 - binary_accuracy: 0.9420 - val_loss: 0.2466 - val_binary_accuracy: 0.9118 - 3s/epoch - 336ms/step
# Epoch 53/150
# 9/9 - 3s - loss: 0.1888 - binary_accuracy: 0.9420 - val_loss: 0.2923 - val_binary_accuracy: 0.8824 - 3s/epoch - 350ms/step
# Epoch 54/150
# 9/9 - 3s - loss: 0.2045 - binary_accuracy: 0.9130 - val_loss: 0.2632 - val_binary_accuracy: 0.8971 - 3s/epoch - 347ms/step
# Epoch 55/150
# 9/9 - 3s - loss: 0.1890 - binary_accuracy: 0.9275 - val_loss: 0.2697 - val_binary_accuracy: 0.8676 - 3s/epoch - 363ms/step
# Epoch 56/150
# 9/9 - 3s - loss: 0.1557 - binary_accuracy: 0.9312 - val_loss: 0.2695 - val_binary_accuracy: 0.8676 - 3s/epoch - 368ms/step
# Epoch 57/150
# 9/9 - 3s - loss: 0.2058 - binary_accuracy: 0.9167 - val_loss: 0.2687 - val_binary_accuracy: 0.8971 - 3s/epoch - 364ms/step
# Epoch 58/150
# 9/9 - 3s - loss: 0.1602 - binary_accuracy: 0.9420 - val_loss: 0.2452 - val_binary_accuracy: 0.8971 - 3s/epoch - 343ms/step
# Epoch 59/150
# 9/9 - 3s - loss: 0.1751 - binary_accuracy: 0.9275 - val_loss: 0.2759 - val_binary_accuracy: 0.8676 - 3s/epoch - 359ms/step
# Epoch 60/150
# 9/9 - 3s - loss: 0.1960 - binary_accuracy: 0.9094 - val_loss: 0.2777 - val_binary_accuracy: 0.8971 - 3s/epoch - 343ms/step
# Epoch 61/150
# 9/9 - 3s - loss: 0.1479 - binary_accuracy: 0.9312 - val_loss: 0.3673 - val_binary_accuracy: 0.8529 - 3s/epoch - 346ms/step
# Epoch 62/150
# 9/9 - 3s - loss: 0.1993 - binary_accuracy: 0.9130 - val_loss: 0.2254 - val_binary_accuracy: 0.9118 - 3s/epoch - 341ms/step
# Epoch 63/150
# 9/9 - 3s - loss: 0.1524 - binary_accuracy: 0.9275 - val_loss: 0.2140 - val_binary_accuracy: 0.9118 - 3s/epoch - 343ms/step
# Epoch 64/150
# 9/9 - 3s - loss: 0.1570 - binary_accuracy: 0.9565 - val_loss: 0.2291 - val_binary_accuracy: 0.8971 - 3s/epoch - 335ms/step
# Epoch 65/150
# 9/9 - 3s - loss: 0.1974 - binary_accuracy: 0.9239 - val_loss: 0.2309 - val_binary_accuracy: 0.8676 - 3s/epoch - 350ms/step
# Epoch 66/150
# 9/9 - 3s - loss: 0.1927 - binary_accuracy: 0.9167 - val_loss: 0.2479 - val_binary_accuracy: 0.8971 - 3s/epoch - 346ms/step
# Epoch 67/150
# 9/9 - 3s - loss: 0.1768 - binary_accuracy: 0.9275 - val_loss: 0.3126 - val_binary_accuracy: 0.8529 - 3s/epoch - 334ms/step
# Epoch 68/150
# 9/9 - 3s - loss: 0.1711 - binary_accuracy: 0.9457 - val_loss: 0.2746 - val_binary_accuracy: 0.8824 - 3s/epoch - 342ms/step
# Epoch 69/150
# 9/9 - 3s - loss: 0.1410 - binary_accuracy: 0.9457 - val_loss: 0.3586 - val_binary_accuracy: 0.8382 - 3s/epoch - 344ms/step
# Epoch 70/150
# 9/9 - 3s - loss: 0.1454 - binary_accuracy: 0.9457 - val_loss: 0.3022 - val_binary_accuracy: 0.8529 - 3s/epoch - 350ms/step
# Epoch 71/150
# 9/9 - 3s - loss: 0.1391 - binary_accuracy: 0.9565 - val_loss: 0.2817 - val_binary_accuracy: 0.8676 - 3s/epoch - 341ms/step
# Epoch 72/150
# 9/9 - 3s - loss: 0.1157 - binary_accuracy: 0.9565 - val_loss: 0.2959 - val_binary_accuracy: 0.8971 - 3s/epoch - 339ms/step
# Epoch 73/150
# 9/9 - 3s - loss: 0.1314 - binary_accuracy: 0.9565 - val_loss: 0.2836 - val_binary_accuracy: 0.8971 - 3s/epoch - 345ms/step
# Epoch 74/150
# 9/9 - 3s - loss: 0.1436 - binary_accuracy: 0.9457 - val_loss: 0.2403 - val_binary_accuracy: 0.9118 - 3s/epoch - 336ms/step
# Epoch 75/150
# 9/9 - 3s - loss: 0.1353 - binary_accuracy: 0.9457 - val_loss: 0.2510 - val_binary_accuracy: 0.8824 - 3s/epoch - 337ms/step
# Epoch 76/150
# 9/9 - 3s - loss: 0.1318 - binary_accuracy: 0.9420 - val_loss: 0.2892 - val_binary_accuracy: 0.8382 - 3s/epoch - 336ms/step
# Epoch 77/150
# 9/9 - 3s - loss: 0.2009 - binary_accuracy: 0.9348 - val_loss: 0.3111 - val_binary_accuracy: 0.8382 - 3s/epoch - 333ms/step
# Epoch 78/150
# 9/9 - 3s - loss: 0.1459 - binary_accuracy: 0.9384 - val_loss: 0.2978 - val_binary_accuracy: 0.8676 - 3s/epoch - 350ms/step
# Epoch 79/150
# 9/9 - 3s - loss: 0.1479 - binary_accuracy: 0.9457 - val_loss: 0.3092 - val_binary_accuracy: 0.8382 - 3s/epoch - 348ms/step
# Epoch 80/150
# 9/9 - 3s - loss: 0.1157 - binary_accuracy: 0.9565 - val_loss: 0.2562 - val_binary_accuracy: 0.8676 - 3s/epoch - 340ms/step
# Epoch 81/150
# 9/9 - 3s - loss: 0.1295 - binary_accuracy: 0.9384 - val_loss: 0.3155 - val_binary_accuracy: 0.8382 - 3s/epoch - 344ms/step
# Epoch 82/150
# 9/9 - 3s - loss: 0.1026 - binary_accuracy: 0.9601 - val_loss: 0.2718 - val_binary_accuracy: 0.8676 - 3s/epoch - 347ms/step
# Epoch 83/150
# 9/9 - 3s - loss: 0.1347 - binary_accuracy: 0.9565 - val_loss: 0.2831 - val_binary_accuracy: 0.8529 - 3s/epoch - 347ms/step
# Epoch 84/150
# 9/9 - 3s - loss: 0.1279 - binary_accuracy: 0.9493 - val_loss: 0.3017 - val_binary_accuracy: 0.8676 - 3s/epoch - 334ms/step
# Epoch 85/150
# 9/9 - 3s - loss: 0.1070 - binary_accuracy: 0.9601 - val_loss: 0.3120 - val_binary_accuracy: 0.8676 - 3s/epoch - 342ms/step
# Epoch 86/150
# 9/9 - 3s - loss: 0.0824 - binary_accuracy: 0.9638 - val_loss: 0.4459 - val_binary_accuracy: 0.8235 - 3s/epoch - 337ms/step
# Epoch 87/150
# 9/9 - 3s - loss: 0.1773 - binary_accuracy: 0.9312 - val_loss: 0.2805 - val_binary_accuracy: 0.8824 - 3s/epoch - 337ms/step
# Epoch 88/150
# 9/9 - 3s - loss: 0.1118 - binary_accuracy: 0.9638 - val_loss: 0.2437 - val_binary_accuracy: 0.8824 - 3s/epoch - 335ms/step
# Epoch 89/150
# 9/9 - 3s - loss: 0.1324 - binary_accuracy: 0.9420 - val_loss: 0.2609 - val_binary_accuracy: 0.8676 - 3s/epoch - 332ms/step
# Epoch 90/150
# 9/9 - 3s - loss: 0.1078 - binary_accuracy: 0.9601 - val_loss: 0.2414 - val_binary_accuracy: 0.8529 - 3s/epoch - 336ms/step
# Epoch 91/150
# 9/9 - 3s - loss: 0.1463 - binary_accuracy: 0.9312 - val_loss: 0.4302 - val_binary_accuracy: 0.7941 - 3s/epoch - 332ms/step
# Epoch 92/150
# 9/9 - 3s - loss: 0.1317 - binary_accuracy: 0.9457 - val_loss: 0.4850 - val_binary_accuracy: 0.7794 - 3s/epoch - 335ms/step
# Epoch 93/150
# 9/9 - 3s - loss: 0.1412 - binary_accuracy: 0.9348 - val_loss: 0.2727 - val_binary_accuracy: 0.8676 - 3s/epoch - 340ms/step
# Epoch 94/150
# 9/9 - 3s - loss: 0.0850 - binary_accuracy: 0.9710 - val_loss: 0.2574 - val_binary_accuracy: 0.8824 - 3s/epoch - 336ms/step
# Epoch 95/150
# 9/9 - 3s - loss: 0.1086 - binary_accuracy: 0.9529 - val_loss: 0.2943 - val_binary_accuracy: 0.8676 - 3s/epoch - 345ms/step
# Epoch 96/150
# 9/9 - 3s - loss: 0.1083 - binary_accuracy: 0.9420 - val_loss: 0.2682 - val_binary_accuracy: 0.8676 - 3s/epoch - 334ms/step
# Epoch 97/150
# 9/9 - 3s - loss: 0.1104 - binary_accuracy: 0.9601 - val_loss: 0.3276 - val_binary_accuracy: 0.8382 - 3s/epoch - 340ms/step
# Epoch 98/150
# 9/9 - 3s - loss: 0.1050 - binary_accuracy: 0.9674 - val_loss: 0.2401 - val_binary_accuracy: 0.8824 - 3s/epoch - 340ms/step
# Epoch 99/150
# 9/9 - 3s - loss: 0.0900 - binary_accuracy: 0.9565 - val_loss: 0.3024 - val_binary_accuracy: 0.8529 - 3s/epoch - 358ms/step
# Epoch 100/150
# 9/9 - 3s - loss: 0.1368 - binary_accuracy: 0.9529 - val_loss: 0.3078 - val_binary_accuracy: 0.8676 - 3s/epoch - 346ms/step
# Epoch 101/150
# 9/9 - 3s - loss: 0.1054 - binary_accuracy: 0.9638 - val_loss: 0.3863 - val_binary_accuracy: 0.8235 - 3s/epoch - 353ms/step
# Epoch 102/150
# 9/9 - 3s - loss: 0.0799 - binary_accuracy: 0.9746 - val_loss: 0.3371 - val_binary_accuracy: 0.8824 - 3s/epoch - 340ms/step
# Epoch 103/150
# 9/9 - 3s - loss: 0.0674 - binary_accuracy: 0.9674 - val_loss: 0.4582 - val_binary_accuracy: 0.8529 - 3s/epoch - 343ms/step
# Epoch 104/150
# 9/9 - 3s - loss: 0.1162 - binary_accuracy: 0.9674 - val_loss: 0.3076 - val_binary_accuracy: 0.8676 - 3s/epoch - 339ms/step
# Epoch 105/150
# 9/9 - 3s - loss: 0.1153 - binary_accuracy: 0.9529 - val_loss: 0.2760 - val_binary_accuracy: 0.8824 - 3s/epoch - 337ms/step
# Epoch 106/150
# 9/9 - 3s - loss: 0.0702 - binary_accuracy: 0.9855 - val_loss: 0.2480 - val_binary_accuracy: 0.8824 - 3s/epoch - 353ms/step
# Epoch 107/150
# 9/9 - 3s - loss: 0.1033 - binary_accuracy: 0.9638 - val_loss: 0.3082 - val_binary_accuracy: 0.8529 - 3s/epoch - 357ms/step
# Epoch 108/150
# 9/9 - 3s - loss: 0.1071 - binary_accuracy: 0.9529 - val_loss: 0.2923 - val_binary_accuracy: 0.8824 - 3s/epoch - 364ms/step
# Epoch 109/150
# 9/9 - 3s - loss: 0.0808 - binary_accuracy: 0.9746 - val_loss: 0.4236 - val_binary_accuracy: 0.8382 - 3s/epoch - 353ms/step
# Epoch 110/150
# 9/9 - 3s - loss: 0.0802 - binary_accuracy: 0.9710 - val_loss: 0.2746 - val_binary_accuracy: 0.8971 - 3s/epoch - 367ms/step
# Epoch 111/150
# 9/9 - 3s - loss: 0.0641 - binary_accuracy: 0.9783 - val_loss: 0.3255 - val_binary_accuracy: 0.8676 - 3s/epoch - 363ms/step
# Epoch 112/150
# 9/9 - 3s - loss: 0.0857 - binary_accuracy: 0.9674 - val_loss: 0.3969 - val_binary_accuracy: 0.8382 - 3s/epoch - 346ms/step
# Epoch 113/150
# 9/9 - 3s - loss: 0.0870 - binary_accuracy: 0.9601 - val_loss: 0.2469 - val_binary_accuracy: 0.8676 - 3s/epoch - 352ms/step
# Epoch 114/150
# 9/9 - 3s - loss: 0.0751 - binary_accuracy: 0.9746 - val_loss: 0.2279 - val_binary_accuracy: 0.8824 - 3s/epoch - 346ms/step
# Epoch 115/150
# 9/9 - 3s - loss: 0.0957 - binary_accuracy: 0.9601 - val_loss: 0.3370 - val_binary_accuracy: 0.8529 - 3s/epoch - 342ms/step
# Epoch 116/150
# 9/9 - 3s - loss: 0.0809 - binary_accuracy: 0.9746 - val_loss: 0.2907 - val_binary_accuracy: 0.8676 - 3s/epoch - 347ms/step
# Epoch 117/150
# 9/9 - 3s - loss: 0.1081 - binary_accuracy: 0.9493 - val_loss: 0.2769 - val_binary_accuracy: 0.8971 - 3s/epoch - 365ms/step
# Epoch 118/150
# 9/9 - 3s - loss: 0.0685 - binary_accuracy: 0.9710 - val_loss: 0.3449 - val_binary_accuracy: 0.8529 - 3s/epoch - 340ms/step
# Epoch 119/150
# 9/9 - 3s - loss: 0.0781 - binary_accuracy: 0.9674 - val_loss: 0.3294 - val_binary_accuracy: 0.8676 - 3s/epoch - 352ms/step
# Epoch 120/150
# 9/9 - 3s - loss: 0.0859 - binary_accuracy: 0.9710 - val_loss: 0.3313 - val_binary_accuracy: 0.8824 - 3s/epoch - 356ms/step
# Epoch 121/150
# 9/9 - 3s - loss: 0.0825 - binary_accuracy: 0.9710 - val_loss: 0.3546 - val_binary_accuracy: 0.8382 - 3s/epoch - 356ms/step
# Epoch 122/150
# 9/9 - 3s - loss: 0.1223 - binary_accuracy: 0.9384 - val_loss: 0.3451 - val_binary_accuracy: 0.8382 - 3s/epoch - 355ms/step
# Epoch 123/150
# 9/9 - 3s - loss: 0.1476 - binary_accuracy: 0.9493 - val_loss: 0.3012 - val_binary_accuracy: 0.8824 - 3s/epoch - 351ms/step
# Epoch 124/150
# 9/9 - 3s - loss: 0.1518 - binary_accuracy: 0.9348 - val_loss: 0.2880 - val_binary_accuracy: 0.8824 - 3s/epoch - 347ms/step
# Epoch 125/150
# 9/9 - 3s - loss: 0.0994 - binary_accuracy: 0.9565 - val_loss: 0.2844 - val_binary_accuracy: 0.8676 - 3s/epoch - 348ms/step
# Epoch 126/150
# 9/9 - 3s - loss: 0.0527 - binary_accuracy: 0.9855 - val_loss: 0.3621 - val_binary_accuracy: 0.8529 - 3s/epoch - 353ms/step
# Epoch 127/150
# 9/9 - 3s - loss: 0.0909 - binary_accuracy: 0.9674 - val_loss: 0.3214 - val_binary_accuracy: 0.8529 - 3s/epoch - 348ms/step
# Epoch 128/150
# 9/9 - 3s - loss: 0.0974 - binary_accuracy: 0.9529 - val_loss: 0.2724 - val_binary_accuracy: 0.8676 - 3s/epoch - 343ms/step
# Epoch 129/150
# 9/9 - 3s - loss: 0.0602 - binary_accuracy: 0.9783 - val_loss: 0.2727 - val_binary_accuracy: 0.8676 - 3s/epoch - 332ms/step
# Epoch 130/150
# 9/9 - 3s - loss: 0.0806 - binary_accuracy: 0.9710 - val_loss: 0.2728 - val_binary_accuracy: 0.8676 - 3s/epoch - 345ms/step
# Epoch 131/150
# 9/9 - 3s - loss: 0.0689 - binary_accuracy: 0.9746 - val_loss: 0.2794 - val_binary_accuracy: 0.8824 - 3s/epoch - 355ms/step
# Epoch 132/150
# 9/9 - 3s - loss: 0.0823 - binary_accuracy: 0.9674 - val_loss: 0.3149 - val_binary_accuracy: 0.8676 - 3s/epoch - 363ms/step
# Epoch 133/150
# 9/9 - 3s - loss: 0.0705 - binary_accuracy: 0.9674 - val_loss: 0.2650 - val_binary_accuracy: 0.8824 - 3s/epoch - 364ms/step
# Epoch 134/150
# 9/9 - 3s - loss: 0.0651 - binary_accuracy: 0.9783 - val_loss: 0.2691 - val_binary_accuracy: 0.8824 - 3s/epoch - 367ms/step
# Epoch 135/150
# 9/9 - 3s - loss: 0.0511 - binary_accuracy: 0.9783 - val_loss: 0.3416 - val_binary_accuracy: 0.8971 - 3s/epoch - 372ms/step
# Epoch 136/150
# 9/9 - 3s - loss: 0.0621 - binary_accuracy: 0.9710 - val_loss: 0.3373 - val_binary_accuracy: 0.8676 - 3s/epoch - 354ms/step
# Epoch 137/150
# 9/9 - 3s - loss: 0.0872 - binary_accuracy: 0.9601 - val_loss: 0.2259 - val_binary_accuracy: 0.8676 - 3s/epoch - 355ms/step
# Epoch 138/150
# 9/9 - 3s - loss: 0.0668 - binary_accuracy: 0.9819 - val_loss: 0.3564 - val_binary_accuracy: 0.8824 - 3s/epoch - 358ms/step
# Epoch 139/150
# 9/9 - 3s - loss: 0.0579 - binary_accuracy: 0.9819 - val_loss: 0.2576 - val_binary_accuracy: 0.8824 - 3s/epoch - 341ms/step
# Epoch 140/150
# 9/9 - 3s - loss: 0.0616 - binary_accuracy: 0.9819 - val_loss: 0.2928 - val_binary_accuracy: 0.8824 - 3s/epoch - 350ms/step
# Epoch 141/150
# 9/9 - 3s - loss: 0.0526 - binary_accuracy: 0.9783 - val_loss: 0.3840 - val_binary_accuracy: 0.8529 - 3s/epoch - 335ms/step
# Epoch 142/150
# 9/9 - 3s - loss: 0.0529 - binary_accuracy: 0.9783 - val_loss: 0.3639 - val_binary_accuracy: 0.8824 - 3s/epoch - 332ms/step
# Epoch 143/150
# 9/9 - 3s - loss: 0.0499 - binary_accuracy: 0.9855 - val_loss: 0.3403 - val_binary_accuracy: 0.8824 - 3s/epoch - 333ms/step
# Epoch 144/150
# 9/9 - 3s - loss: 0.0498 - binary_accuracy: 0.9891 - val_loss: 0.3153 - val_binary_accuracy: 0.8824 - 3s/epoch - 338ms/step
# Epoch 145/150
# 9/9 - 3s - loss: 0.0586 - binary_accuracy: 0.9819 - val_loss: 0.3193 - val_binary_accuracy: 0.8824 - 3s/epoch - 346ms/step
# Epoch 146/150
# 9/9 - 3s - loss: 0.0539 - binary_accuracy: 0.9783 - val_loss: 0.3643 - val_binary_accuracy: 0.8676 - 3s/epoch - 350ms/step
# Epoch 147/150
# 9/9 - 3s - loss: 0.0613 - binary_accuracy: 0.9891 - val_loss: 0.3244 - val_binary_accuracy: 0.8824 - 3s/epoch - 360ms/step
# Epoch 148/150
# 9/9 - 3s - loss: 0.0352 - binary_accuracy: 0.9928 - val_loss: 0.3234 - val_binary_accuracy: 0.8971 - 3s/epoch - 337ms/step
# Epoch 149/150
# 9/9 - 3s - loss: 0.0341 - binary_accuracy: 1.0000 - val_loss: 0.3751 - val_binary_accuracy: 0.8676 - 3s/epoch - 337ms/step
# Epoch 150/150
# 9/9 - 3s - loss: 0.0675 - binary_accuracy: 0.9746 - val_loss: 0.2857 - val_binary_accuracy: 0.8529 - 3s/epoch - 335ms/step

# %%
#accuracy
plt.plot(result.history['binary_accuracy'])
plt.plot(result.history['val_binary_accuracy'])
# plt.plot(result.history['accuracy'])
# plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# OPTIONAL: Decide if best weights should be loaded from previous model based on val_acc
# The model weights (that are considered the best) are loaded into the model.
result = model.load_weights(checkpoint_filepath)

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model
model.save("Models/VGG19/VGG19_covid_classification.h5")

os.chdir(destination)

# %% [markdown]
# <h3>Evaluate Test data</h3>

# %%
print(sum(cb.logs) / 150)

testLoss, testAcc = model.evaluate(test)
print('''
Test Loss: {}
Test Accuracy: {}
'''.format(testLoss, testAcc))
# Out:
# 3.235955528666685
# 3/3 [==============================] - 3s 1s/step - loss: 0.2750 - binary_accuracy: 0.8953
#
# Test Loss: 0.2750069499015808
# Test Accuracy: 0.895348846912384

# %% [markdown]
# <h4>*Optional - Fine tune model with two-step training*</h4>

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

mobile.trainable = True

for layer in mobile.layers[:-2]:
    layer.trainable = False
    
#re-train the model at a very low learning rate
model.compile(optimizer=Adam(learning_rate=0.00006), loss='binary_crossentropy', metrics=['binary_accuracy'])

result = model.fit(x=train, validation_data=validation, epochs=100, verbose=2, callbacks=[cb, es])
# Out:
# Epoch 1/100
# 9/9 - 4s - loss: 0.2567 - binary_accuracy: 0.9022 - val_loss: 0.2851 - val_binary_accuracy: 0.8676 - 4s/epoch - 448ms/step
# Epoch 2/100
# 9/9 - 3s - loss: 0.2512 - binary_accuracy: 0.8913 - val_loss: 0.2595 - val_binary_accuracy: 0.8676 - 3s/epoch - 340ms/step
# Epoch 3/100
# 9/9 - 3s - loss: 0.2208 - binary_accuracy: 0.9022 - val_loss: 0.2612 - val_binary_accuracy: 0.8824 - 3s/epoch - 346ms/step
# Epoch 4/100
# 9/9 - 3s - loss: 0.2277 - binary_accuracy: 0.9167 - val_loss: 0.2676 - val_binary_accuracy: 0.8824 - 3s/epoch - 337ms/step
# Epoch 5/100
# 9/9 - 3s - loss: 0.2113 - binary_accuracy: 0.9203 - val_loss: 0.2719 - val_binary_accuracy: 0.8824 - 3s/epoch - 335ms/step
# Epoch 6/100
# 9/9 - 3s - loss: 0.2432 - binary_accuracy: 0.8949 - val_loss: 0.2792 - val_binary_accuracy: 0.8824 - 3s/epoch - 334ms/step
# Epoch 7/100
# 9/9 - 3s - loss: 0.2129 - binary_accuracy: 0.9130 - val_loss: 0.2930 - val_binary_accuracy: 0.8529 - 3s/epoch - 337ms/step
# Epoch 8/100
# 9/9 - 3s - loss: 0.2315 - binary_accuracy: 0.9130 - val_loss: 0.3040 - val_binary_accuracy: 0.8382 - 3s/epoch - 340ms/step
# Epoch 9/100
# 9/9 - 3s - loss: 0.2048 - binary_accuracy: 0.9094 - val_loss: 0.2766 - val_binary_accuracy: 0.8676 - 3s/epoch - 346ms/step
# Epoch 10/100
# 9/9 - 3s - loss: 0.1967 - binary_accuracy: 0.9275 - val_loss: 0.2737 - val_binary_accuracy: 0.8676 - 3s/epoch - 371ms/step
# Epoch 11/100
# 9/9 - 3s - loss: 0.2031 - binary_accuracy: 0.9239 - val_loss: 0.2759 - val_binary_accuracy: 0.8676 - 3s/epoch - 343ms/step
# Epoch 12/100
# 9/9 - 3s - loss: 0.2237 - binary_accuracy: 0.9130 - val_loss: 0.3043 - val_binary_accuracy: 0.8382 - 3s/epoch - 379ms/step
# Epoch 12: early stopping

# %% [markdown]
# <h3>Accuracy and Loss graph</h3>

# %%
#accuracy
plt.plot(result.history['binary_accuracy'])
plt.plot(result.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# <h3>Classification report</h3>

# %%
predictions = model.predict(test, verbose=0)
# predictions = predictions.reshape(1,-1)[0]
# lst = np.argmax(predictions, axis= 1)
lst = (predictions > 0.5).astype(int)

print(classification_report(test.classes, lst, target_names = test.class_indices))
# Out:
#               precision    recall  f1-score   support
#
#        covid       0.97      0.78      0.86        36
#       normal       0.86      0.98      0.92        50
#
#     accuracy                           0.90        86
#    macro avg       0.91      0.88      0.89        86
# weighted avg       0.90      0.90      0.89        86

# %% [markdown]
# <h3>Confusion matrix</h3>

# %%
result = confusion_matrix(test.classes, lst)
print(result)

def plot_confusion_matrix(result, classes, cmap=plt.cm.Blues):
    plt.subplots(figsize=(7, 7))
    plt.imshow(result, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

    thresh = result.max() / 2.
    for i, j in itertools.product(range(result.shape[0]), range(result.shape[1])):
        plt.text(j, i, result[i, j],
            horizontalalignment="center",
            color = "white" if result[i, j] > thresh else "black")
        
    #current matplotlib version will cut off top and bottom of the matrix, 
    #hence the manual workaround - remove if matplotlib version does not cut off
    b, t = plt.ylim() # discover bottom and top values
    b += 0.5 # Add 0.5 to bottom
    t -= 0.5 # Subtract 0.5 from top
    plt.ylim(b, t) # update ylim(bottom, top) values
    plt.show()
    
plot_confusion_matrix(result, list(test.class_indices.keys()))
# Out:
# [[28  8]
#  [ 1 49]]

# %% [markdown]
# <h3>Save the model</h3>

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model
model.save("Models/VGG19/VGG19_covid_classification_finetuned.h5")
