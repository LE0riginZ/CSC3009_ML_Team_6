# %% [markdown]
# <h3>Import packages</h3>

# %%
from datetime import date
from timeit import default_timer as timer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
# from keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import imagenet_utils
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Configure TensorFlow to use GPU for training
tf.config.list_physical_devices('GPU') 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_physical_devices('GPU')
#Set GPU memory limit so my GPU doesn't crash
if gpus:
    try:
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <h3>Create class to record time taken to train the model</h3>

# %%
#class to record time taken to train per epoch
class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

# %% [markdown]
# <h3>Create train and test folder</h3>

# %%
#creates a folder each time the set of code is run to sort dataset into train and test
day = date.today()
formatDate = day.strftime("%b-%d-%Y")

#create folder with current date to group predictions ran in a day together, if it does not exists
if os.path.isdir('Prediction (' + formatDate + ')') is False:
    folder = os.mkdir('Prediction (' + formatDate + ')')
folder = 'Prediction (' + formatDate + ')'

#looping through to find if destination folder exists
i = 1
while True:
    if os.path.isdir(folder + '/dataset_6 - ' + str(i)) is False:
        break
    i += 1

#destination path for unsorted folder
destination = folder + '/dataset_6 - ' + str(i)

#source path for unsorted folder
source = 'dataset_6/'

#duplicate the unsorted folder from source to destination
shutil.copytree(source, destination)

os.mkdir(destination + '/train')
os.mkdir(destination + '/test')

# %% [markdown]
# <h3>Sort dataset into train and test folder</h3>

# %%
#function to split images into training (80%) and testing (20%) and return both
def split(data):
    num = int(len(data) * 0.8)
    # num = int(len(data) * 0.9) #90/10 split
#     num = int(len(data) * 0.7) #70/30 split
    random.shuffle(data)
    return data[:num], data[num:]

dir = os.chdir(destination)
for category in os.listdir(dir):
    #skip the iteration if folder is "train" or "test"
    skip = ['train', 'test']
    if category in skip:
        continue
    
    shutil.move(f'{category}', 'train')
    #create a subfolder with the same name in test
    os.mkdir(f'test/{category}')

    #get the images in each folder (battery type) for spltting of data into training and testing
    img = os.listdir(f'train/{category}')
    training, testing = split(img)
    
    for file in testing:
        shutil.move(f'train/{category}/{file}', f'test/{category}')

# %% [markdown]
# <h3>Transfer Learning</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.ResNet50V2(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %%
mobile.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 7, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 23,519,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
for layer in mobile.layers[:-2]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))
x = mobile(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(1, activation="sigmoid")(x)  

model = keras.Model(inputs, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 23,566,849
# Trainable params: 6,145
# Non-trainable params: 23,560,704
# _________________________________________________________________

# %% [markdown]
# <h3>Process data</h3>

# %%
train_path = 'train'
test_path = 'test'

#for data augmentation on training data
datagen = ImageDataGenerator( 
    preprocessing_function =tf.keras.applications.resnet50.preprocess_input,
    validation_split=0.2,
    # validation_split=0.1, #changes made for 90/10 split
    rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.2, # Randomly zoom image 
    width_shift_range = 0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range = 0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip = True,  # randomly flip images
#     vertical_flip = False,    # randomly flip images
    vertical_flip = True, #include vertical flip for better generalisation
    )  

#takes images from directory path and generates batches of augmented data
train = datagen.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    class_mode = 'binary',
    batch_size=32,
    subset='training',
        shuffle = False)

#for validation data
validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input, 
                                        validation_split=0.2)
# validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
#                                         validation_split=0.1) #changes made for 90/10 split


validation = validation_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    class_mode = 'binary',
    batch_size=32,
    subset='validation',
        shuffle = False)

#for test data
test = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input)\
.flow_from_directory(directory=test_path, target_size=(224,224), class_mode = 'binary', batch_size=32, shuffle=False)
# Out:
# Found 276 images belonging to 2 classes.
# Found 68 images belonging to 2 classes.
# Found 86 images belonging to 2 classes.

# %% [markdown]
# <h3>Train model</h3>

# %%
model.compile(optimizer=Adam(learning_rate=0.0006), loss='binary_crossentropy', metrics=['binary_accuracy']) #Last best setting
# model.compile(optimizer=Adam(learning_rate=0.006), loss='binary_crossentropy', metrics=['accuracy']) #Last best setting

checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_binary_accuracy',
    # monitor='val_accuracy',
    mode='max',
    save_best_only=True) #save best model

#more epochs for better results
result = model.fit(x=train, validation_data=validation, epochs=150, verbose=2, callbacks=[model_checkpoint_callback,cb])
# Out:
# Epoch 1/150
# 9/9 - 18s - loss: 221.1296 - binary_accuracy: 0.5507 - val_loss: 123.7536 - val_binary_accuracy: 0.5882 - 18s/epoch - 2s/step
# Epoch 2/150
# 9/9 - 3s - loss: 116.9172 - binary_accuracy: 0.5616 - val_loss: 23.6745 - val_binary_accuracy: 0.5441 - 3s/epoch - 319ms/step
# Epoch 3/150
# 9/9 - 3s - loss: 137.2417 - binary_accuracy: 0.4275 - val_loss: 61.5264 - val_binary_accuracy: 0.4118 - 3s/epoch - 328ms/step
# Epoch 4/150
# 9/9 - 3s - loss: 131.9076 - binary_accuracy: 0.4855 - val_loss: 20.9015 - val_binary_accuracy: 0.5588 - 3s/epoch - 321ms/step
# Epoch 5/150
# 9/9 - 3s - loss: 114.6943 - binary_accuracy: 0.4964 - val_loss: 23.1508 - val_binary_accuracy: 0.5588 - 3s/epoch - 317ms/step
# Epoch 6/150
# 9/9 - 3s - loss: 107.6479 - binary_accuracy: 0.5471 - val_loss: 12.6799 - val_binary_accuracy: 0.6029 - 3s/epoch - 386ms/step
# Epoch 7/150
# 9/9 - 3s - loss: 117.2321 - binary_accuracy: 0.5145 - val_loss: 13.3454 - val_binary_accuracy: 0.6029 - 3s/epoch - 324ms/step
# Epoch 8/150
# 9/9 - 3s - loss: 109.8076 - binary_accuracy: 0.5217 - val_loss: 36.4444 - val_binary_accuracy: 0.5882 - 3s/epoch - 315ms/step
# Epoch 9/150
# 9/9 - 3s - loss: 103.8217 - binary_accuracy: 0.6014 - val_loss: 27.2797 - val_binary_accuracy: 0.5735 - 3s/epoch - 317ms/step
# Epoch 10/150
# 9/9 - 3s - loss: 122.9562 - binary_accuracy: 0.5109 - val_loss: 21.7911 - val_binary_accuracy: 0.5588 - 3s/epoch - 320ms/step
# Epoch 11/150
# 9/9 - 3s - loss: 91.4329 - binary_accuracy: 0.5435 - val_loss: 19.6921 - val_binary_accuracy: 0.5588 - 3s/epoch - 326ms/step
# Epoch 12/150
# 9/9 - 3s - loss: 98.2700 - binary_accuracy: 0.5362 - val_loss: 16.4325 - val_binary_accuracy: 0.6618 - 3s/epoch - 376ms/step
# Epoch 13/150
# 9/9 - 3s - loss: 95.5799 - binary_accuracy: 0.4710 - val_loss: 18.8680 - val_binary_accuracy: 0.5735 - 3s/epoch - 320ms/step
# Epoch 14/150
# 9/9 - 3s - loss: 83.1628 - binary_accuracy: 0.5290 - val_loss: 13.0659 - val_binary_accuracy: 0.6471 - 3s/epoch - 331ms/step
# Epoch 15/150
# 9/9 - 4s - loss: 97.8702 - binary_accuracy: 0.5254 - val_loss: 12.5996 - val_binary_accuracy: 0.6912 - 4s/epoch - 389ms/step
# Epoch 16/150
# 9/9 - 3s - loss: 82.1283 - binary_accuracy: 0.5652 - val_loss: 17.9721 - val_binary_accuracy: 0.6029 - 3s/epoch - 328ms/step
# Epoch 17/150
# 9/9 - 3s - loss: 85.7123 - binary_accuracy: 0.5326 - val_loss: 16.6442 - val_binary_accuracy: 0.6029 - 3s/epoch - 319ms/step
# Epoch 18/150
# 9/9 - 3s - loss: 86.7760 - binary_accuracy: 0.5399 - val_loss: 20.6935 - val_binary_accuracy: 0.6029 - 3s/epoch - 322ms/step
# Epoch 19/150
# 9/9 - 3s - loss: 95.0889 - binary_accuracy: 0.5507 - val_loss: 14.8623 - val_binary_accuracy: 0.6324 - 3s/epoch - 316ms/step
# Epoch 20/150
# 9/9 - 3s - loss: 82.1751 - binary_accuracy: 0.5362 - val_loss: 13.4225 - val_binary_accuracy: 0.6912 - 3s/epoch - 313ms/step
# Epoch 21/150
# 9/9 - 3s - loss: 87.2102 - binary_accuracy: 0.5254 - val_loss: 12.3060 - val_binary_accuracy: 0.7059 - 3s/epoch - 374ms/step
# Epoch 22/150
# 9/9 - 3s - loss: 94.9887 - binary_accuracy: 0.5145 - val_loss: 17.9268 - val_binary_accuracy: 0.6176 - 3s/epoch - 318ms/step
# Epoch 23/150
# 9/9 - 3s - loss: 94.4181 - binary_accuracy: 0.5072 - val_loss: 11.3340 - val_binary_accuracy: 0.7059 - 3s/epoch - 318ms/step
# Epoch 24/150
# 9/9 - 3s - loss: 69.4783 - binary_accuracy: 0.5688 - val_loss: 16.2337 - val_binary_accuracy: 0.6324 - 3s/epoch - 320ms/step
# Epoch 25/150
# 9/9 - 3s - loss: 73.7547 - binary_accuracy: 0.5761 - val_loss: 15.6817 - val_binary_accuracy: 0.6471 - 3s/epoch - 322ms/step
# Epoch 26/150
# 9/9 - 3s - loss: 93.6191 - binary_accuracy: 0.4891 - val_loss: 13.7018 - val_binary_accuracy: 0.6471 - 3s/epoch - 316ms/step
# Epoch 27/150
# 9/9 - 4s - loss: 86.0766 - binary_accuracy: 0.4855 - val_loss: 10.4316 - val_binary_accuracy: 0.7353 - 4s/epoch - 397ms/step
# Epoch 28/150
# 9/9 - 3s - loss: 88.1855 - binary_accuracy: 0.5145 - val_loss: 11.7738 - val_binary_accuracy: 0.6765 - 3s/epoch - 324ms/step
# Epoch 29/150
# 9/9 - 3s - loss: 69.0914 - binary_accuracy: 0.5616 - val_loss: 11.2094 - val_binary_accuracy: 0.6765 - 3s/epoch - 316ms/step
# Epoch 30/150
# 9/9 - 3s - loss: 76.3365 - binary_accuracy: 0.5254 - val_loss: 10.6249 - val_binary_accuracy: 0.6912 - 3s/epoch - 328ms/step
# Epoch 31/150
# 9/9 - 3s - loss: 81.2625 - binary_accuracy: 0.5254 - val_loss: 17.4300 - val_binary_accuracy: 0.6324 - 3s/epoch - 319ms/step
# Epoch 32/150
# 9/9 - 3s - loss: 71.1760 - binary_accuracy: 0.5507 - val_loss: 10.2345 - val_binary_accuracy: 0.7353 - 3s/epoch - 319ms/step
# Epoch 33/150
# 9/9 - 3s - loss: 66.2148 - binary_accuracy: 0.5543 - val_loss: 11.0996 - val_binary_accuracy: 0.7059 - 3s/epoch - 319ms/step
# Epoch 34/150
# 9/9 - 3s - loss: 79.5915 - binary_accuracy: 0.5072 - val_loss: 20.5479 - val_binary_accuracy: 0.6176 - 3s/epoch - 320ms/step
# Epoch 35/150
# 9/9 - 3s - loss: 81.0562 - binary_accuracy: 0.5000 - val_loss: 10.4508 - val_binary_accuracy: 0.7059 - 3s/epoch - 323ms/step
# Epoch 36/150
# 9/9 - 3s - loss: 50.4412 - binary_accuracy: 0.6449 - val_loss: 10.7153 - val_binary_accuracy: 0.6912 - 3s/epoch - 325ms/step
# Epoch 37/150
# 9/9 - 3s - loss: 69.2651 - binary_accuracy: 0.5254 - val_loss: 34.0587 - val_binary_accuracy: 0.5882 - 3s/epoch - 324ms/step
# Epoch 38/150
# 9/9 - 3s - loss: 67.5175 - binary_accuracy: 0.5326 - val_loss: 8.9418 - val_binary_accuracy: 0.7500 - 3s/epoch - 387ms/step
# Epoch 39/150
# 9/9 - 3s - loss: 68.5613 - binary_accuracy: 0.5254 - val_loss: 16.8094 - val_binary_accuracy: 0.6324 - 3s/epoch - 357ms/step
# Epoch 40/150
# 9/9 - 3s - loss: 59.9229 - binary_accuracy: 0.5870 - val_loss: 9.6934 - val_binary_accuracy: 0.7059 - 3s/epoch - 333ms/step
# Epoch 41/150
# 9/9 - 3s - loss: 43.5401 - binary_accuracy: 0.6051 - val_loss: 12.3621 - val_binary_accuracy: 0.6912 - 3s/epoch - 352ms/step
# Epoch 42/150
# 9/9 - 3s - loss: 68.9953 - binary_accuracy: 0.5797 - val_loss: 14.5551 - val_binary_accuracy: 0.6765 - 3s/epoch - 345ms/step
# Epoch 43/150
# 9/9 - 3s - loss: 59.8894 - binary_accuracy: 0.5761 - val_loss: 9.6310 - val_binary_accuracy: 0.6912 - 3s/epoch - 337ms/step
# Epoch 44/150
# 9/9 - 3s - loss: 60.7891 - binary_accuracy: 0.5217 - val_loss: 13.3244 - val_binary_accuracy: 0.7059 - 3s/epoch - 323ms/step
# Epoch 45/150
# 9/9 - 3s - loss: 61.2584 - binary_accuracy: 0.5543 - val_loss: 12.0177 - val_binary_accuracy: 0.6912 - 3s/epoch - 338ms/step
# Epoch 46/150
# 9/9 - 3s - loss: 50.6526 - binary_accuracy: 0.5978 - val_loss: 10.8116 - val_binary_accuracy: 0.7206 - 3s/epoch - 325ms/step
# Epoch 47/150
# 9/9 - 3s - loss: 59.5957 - binary_accuracy: 0.5072 - val_loss: 9.7782 - val_binary_accuracy: 0.7647 - 3s/epoch - 375ms/step
# Epoch 48/150
# 9/9 - 3s - loss: 54.9539 - binary_accuracy: 0.5797 - val_loss: 15.2492 - val_binary_accuracy: 0.6912 - 3s/epoch - 329ms/step
# Epoch 49/150
# 9/9 - 3s - loss: 44.6196 - binary_accuracy: 0.5906 - val_loss: 9.7671 - val_binary_accuracy: 0.6912 - 3s/epoch - 332ms/step
# Epoch 50/150
# 9/9 - 3s - loss: 55.6426 - binary_accuracy: 0.5435 - val_loss: 9.6532 - val_binary_accuracy: 0.7647 - 3s/epoch - 321ms/step
# Epoch 51/150
# 9/9 - 3s - loss: 53.2504 - binary_accuracy: 0.5254 - val_loss: 9.8369 - val_binary_accuracy: 0.7353 - 3s/epoch - 338ms/step
# Epoch 52/150
# 9/9 - 3s - loss: 49.6972 - binary_accuracy: 0.6014 - val_loss: 9.6125 - val_binary_accuracy: 0.7206 - 3s/epoch - 327ms/step
# Epoch 53/150
# 9/9 - 3s - loss: 62.8576 - binary_accuracy: 0.5145 - val_loss: 19.4436 - val_binary_accuracy: 0.6176 - 3s/epoch - 325ms/step
# Epoch 54/150
# 9/9 - 3s - loss: 59.7203 - binary_accuracy: 0.5435 - val_loss: 17.0814 - val_binary_accuracy: 0.6765 - 3s/epoch - 334ms/step
# Epoch 55/150
# 9/9 - 3s - loss: 55.3207 - binary_accuracy: 0.5290 - val_loss: 11.4180 - val_binary_accuracy: 0.7059 - 3s/epoch - 324ms/step
# Epoch 56/150
# 9/9 - 3s - loss: 42.6839 - binary_accuracy: 0.5616 - val_loss: 23.3826 - val_binary_accuracy: 0.6029 - 3s/epoch - 338ms/step
# Epoch 57/150
# 9/9 - 3s - loss: 56.8124 - binary_accuracy: 0.5580 - val_loss: 10.4845 - val_binary_accuracy: 0.7059 - 3s/epoch - 337ms/step
# Epoch 58/150
# 9/9 - 3s - loss: 49.4642 - binary_accuracy: 0.5399 - val_loss: 9.2865 - val_binary_accuracy: 0.7059 - 3s/epoch - 357ms/step
# Epoch 59/150
# 9/9 - 3s - loss: 39.1313 - binary_accuracy: 0.6268 - val_loss: 15.8409 - val_binary_accuracy: 0.6471 - 3s/epoch - 343ms/step
# Epoch 60/150
# 9/9 - 3s - loss: 57.3951 - binary_accuracy: 0.6014 - val_loss: 10.2480 - val_binary_accuracy: 0.7206 - 3s/epoch - 339ms/step
# Epoch 61/150
# 9/9 - 3s - loss: 44.3413 - binary_accuracy: 0.5978 - val_loss: 9.3453 - val_binary_accuracy: 0.7353 - 3s/epoch - 331ms/step
# Epoch 62/150
# 9/9 - 3s - loss: 40.5798 - binary_accuracy: 0.5906 - val_loss: 9.0202 - val_binary_accuracy: 0.7059 - 3s/epoch - 334ms/step
# Epoch 63/150
# 9/9 - 3s - loss: 36.5848 - binary_accuracy: 0.6268 - val_loss: 9.8737 - val_binary_accuracy: 0.7206 - 3s/epoch - 333ms/step
# Epoch 64/150
# 9/9 - 3s - loss: 49.8987 - binary_accuracy: 0.5326 - val_loss: 14.5583 - val_binary_accuracy: 0.6765 - 3s/epoch - 328ms/step
# Epoch 65/150
# 9/9 - 3s - loss: 44.6139 - binary_accuracy: 0.5399 - val_loss: 8.5226 - val_binary_accuracy: 0.7059 - 3s/epoch - 352ms/step
# Epoch 66/150
# 9/9 - 3s - loss: 41.5143 - binary_accuracy: 0.5290 - val_loss: 8.0306 - val_binary_accuracy: 0.7206 - 3s/epoch - 348ms/step
# Epoch 67/150
# 9/9 - 3s - loss: 41.2595 - binary_accuracy: 0.5543 - val_loss: 8.8656 - val_binary_accuracy: 0.7500 - 3s/epoch - 327ms/step
# Epoch 68/150
# 9/9 - 3s - loss: 40.5258 - binary_accuracy: 0.6014 - val_loss: 11.0847 - val_binary_accuracy: 0.6765 - 3s/epoch - 335ms/step
# Epoch 69/150
# 9/9 - 3s - loss: 57.7182 - binary_accuracy: 0.4855 - val_loss: 12.0310 - val_binary_accuracy: 0.6912 - 3s/epoch - 362ms/step
# Epoch 70/150
# 9/9 - 3s - loss: 47.3665 - binary_accuracy: 0.5471 - val_loss: 22.9646 - val_binary_accuracy: 0.6029 - 3s/epoch - 341ms/step
# Epoch 71/150
# 9/9 - 3s - loss: 32.4702 - binary_accuracy: 0.5942 - val_loss: 7.4286 - val_binary_accuracy: 0.6912 - 3s/epoch - 323ms/step
# Epoch 72/150
# 9/9 - 3s - loss: 39.4411 - binary_accuracy: 0.5688 - val_loss: 7.7614 - val_binary_accuracy: 0.7353 - 3s/epoch - 327ms/step
# Epoch 73/150
# 9/9 - 3s - loss: 40.5910 - binary_accuracy: 0.5217 - val_loss: 7.8127 - val_binary_accuracy: 0.7353 - 3s/epoch - 324ms/step
# Epoch 74/150
# 9/9 - 3s - loss: 47.5194 - binary_accuracy: 0.5399 - val_loss: 18.7892 - val_binary_accuracy: 0.6029 - 3s/epoch - 316ms/step
# Epoch 75/150
# 9/9 - 3s - loss: 30.3083 - binary_accuracy: 0.6522 - val_loss: 10.6536 - val_binary_accuracy: 0.7059 - 3s/epoch - 329ms/step
# Epoch 76/150
# 9/9 - 3s - loss: 45.5783 - binary_accuracy: 0.5181 - val_loss: 8.0724 - val_binary_accuracy: 0.7353 - 3s/epoch - 319ms/step
# Epoch 77/150
# 9/9 - 3s - loss: 50.3948 - binary_accuracy: 0.5471 - val_loss: 15.4821 - val_binary_accuracy: 0.6324 - 3s/epoch - 328ms/step
# Epoch 78/150
# 9/9 - 3s - loss: 21.4239 - binary_accuracy: 0.6739 - val_loss: 7.1155 - val_binary_accuracy: 0.6912 - 3s/epoch - 322ms/step
# Epoch 79/150
# 9/9 - 3s - loss: 39.5814 - binary_accuracy: 0.5181 - val_loss: 8.2790 - val_binary_accuracy: 0.7353 - 3s/epoch - 344ms/step
# Epoch 80/150
# 9/9 - 3s - loss: 30.9579 - binary_accuracy: 0.6268 - val_loss: 11.7408 - val_binary_accuracy: 0.6618 - 3s/epoch - 344ms/step
# Epoch 81/150
# 9/9 - 3s - loss: 25.3187 - binary_accuracy: 0.6594 - val_loss: 7.7338 - val_binary_accuracy: 0.6912 - 3s/epoch - 333ms/step
# Epoch 82/150
# 9/9 - 3s - loss: 48.4405 - binary_accuracy: 0.4601 - val_loss: 8.0070 - val_binary_accuracy: 0.7647 - 3s/epoch - 329ms/step
# Epoch 83/150
# 9/9 - 3s - loss: 36.2971 - binary_accuracy: 0.6304 - val_loss: 31.7312 - val_binary_accuracy: 0.5882 - 3s/epoch - 329ms/step
# Epoch 84/150
# 9/9 - 3s - loss: 44.1671 - binary_accuracy: 0.5471 - val_loss: 7.7698 - val_binary_accuracy: 0.7353 - 3s/epoch - 328ms/step
# Epoch 85/150
# 9/9 - 3s - loss: 30.7189 - binary_accuracy: 0.5833 - val_loss: 7.3844 - val_binary_accuracy: 0.7206 - 3s/epoch - 330ms/step
# Epoch 86/150
# 9/9 - 3s - loss: 28.2384 - binary_accuracy: 0.5906 - val_loss: 7.7048 - val_binary_accuracy: 0.7206 - 3s/epoch - 320ms/step
# Epoch 87/150
# 9/9 - 3s - loss: 30.4171 - binary_accuracy: 0.5616 - val_loss: 7.0839 - val_binary_accuracy: 0.7206 - 3s/epoch - 335ms/step
# Epoch 88/150
# 9/9 - 3s - loss: 41.8718 - binary_accuracy: 0.5254 - val_loss: 15.7834 - val_binary_accuracy: 0.6176 - 3s/epoch - 332ms/step
# Epoch 89/150
# 9/9 - 3s - loss: 48.0955 - binary_accuracy: 0.3913 - val_loss: 7.4488 - val_binary_accuracy: 0.7353 - 3s/epoch - 329ms/step
# Epoch 90/150
# 9/9 - 3s - loss: 30.3740 - binary_accuracy: 0.5978 - val_loss: 14.1450 - val_binary_accuracy: 0.6324 - 3s/epoch - 325ms/step
# Epoch 91/150
# 9/9 - 3s - loss: 29.4149 - binary_accuracy: 0.6413 - val_loss: 6.6316 - val_binary_accuracy: 0.7206 - 3s/epoch - 333ms/step
# Epoch 92/150
# 9/9 - 3s - loss: 30.7536 - binary_accuracy: 0.5362 - val_loss: 6.7837 - val_binary_accuracy: 0.7500 - 3s/epoch - 330ms/step
# Epoch 93/150
# 9/9 - 3s - loss: 23.7846 - binary_accuracy: 0.6486 - val_loss: 11.3494 - val_binary_accuracy: 0.6618 - 3s/epoch - 345ms/step
# Epoch 94/150
# 9/9 - 3s - loss: 28.1879 - binary_accuracy: 0.5942 - val_loss: 6.4847 - val_binary_accuracy: 0.7206 - 3s/epoch - 327ms/step
# Epoch 95/150
# 9/9 - 3s - loss: 25.8032 - binary_accuracy: 0.5761 - val_loss: 7.7840 - val_binary_accuracy: 0.7059 - 3s/epoch - 324ms/step
# Epoch 96/150
# 9/9 - 3s - loss: 29.0187 - binary_accuracy: 0.5870 - val_loss: 6.3569 - val_binary_accuracy: 0.7353 - 3s/epoch - 326ms/step
# Epoch 97/150
# 9/9 - 3s - loss: 25.4051 - binary_accuracy: 0.5435 - val_loss: 6.4374 - val_binary_accuracy: 0.7353 - 3s/epoch - 329ms/step
# Epoch 98/150
# 9/9 - 3s - loss: 32.1677 - binary_accuracy: 0.5507 - val_loss: 6.7489 - val_binary_accuracy: 0.7500 - 3s/epoch - 331ms/step
# Epoch 99/150
# 9/9 - 3s - loss: 28.3667 - binary_accuracy: 0.5471 - val_loss: 7.6965 - val_binary_accuracy: 0.6912 - 3s/epoch - 334ms/step
# Epoch 100/150
# 9/9 - 3s - loss: 36.9433 - binary_accuracy: 0.5725 - val_loss: 9.1550 - val_binary_accuracy: 0.6324 - 3s/epoch - 335ms/step
# Epoch 101/150
# 9/9 - 3s - loss: 27.1320 - binary_accuracy: 0.5616 - val_loss: 6.2606 - val_binary_accuracy: 0.7500 - 3s/epoch - 324ms/step
# Epoch 102/150
# 9/9 - 3s - loss: 28.8932 - binary_accuracy: 0.5616 - val_loss: 5.6966 - val_binary_accuracy: 0.7206 - 3s/epoch - 327ms/step
# Epoch 103/150
# 9/9 - 3s - loss: 20.5130 - binary_accuracy: 0.5833 - val_loss: 4.8698 - val_binary_accuracy: 0.7353 - 3s/epoch - 330ms/step
# Epoch 104/150
# 9/9 - 3s - loss: 28.0652 - binary_accuracy: 0.5652 - val_loss: 5.9970 - val_binary_accuracy: 0.7353 - 3s/epoch - 326ms/step
# Epoch 105/150
# 9/9 - 3s - loss: 26.2114 - binary_accuracy: 0.5725 - val_loss: 7.1769 - val_binary_accuracy: 0.7059 - 3s/epoch - 322ms/step
# Epoch 106/150
# 9/9 - 3s - loss: 28.3200 - binary_accuracy: 0.5072 - val_loss: 5.1015 - val_binary_accuracy: 0.7500 - 3s/epoch - 323ms/step
# Epoch 107/150
# 9/9 - 3s - loss: 26.5156 - binary_accuracy: 0.6268 - val_loss: 5.7260 - val_binary_accuracy: 0.7206 - 3s/epoch - 325ms/step
# Epoch 108/150
# 9/9 - 3s - loss: 18.5948 - binary_accuracy: 0.6123 - val_loss: 16.2149 - val_binary_accuracy: 0.5588 - 3s/epoch - 322ms/step
# Epoch 109/150
# 9/9 - 3s - loss: 25.8495 - binary_accuracy: 0.5145 - val_loss: 12.2074 - val_binary_accuracy: 0.6324 - 3s/epoch - 325ms/step
# Epoch 110/150
# 9/9 - 3s - loss: 15.0543 - binary_accuracy: 0.6739 - val_loss: 7.2237 - val_binary_accuracy: 0.7206 - 3s/epoch - 327ms/step
# Epoch 111/150
# 9/9 - 3s - loss: 21.0373 - binary_accuracy: 0.5761 - val_loss: 4.2018 - val_binary_accuracy: 0.7941 - 3s/epoch - 383ms/step
# Epoch 112/150
# 9/9 - 3s - loss: 33.8990 - binary_accuracy: 0.4493 - val_loss: 7.5761 - val_binary_accuracy: 0.6765 - 3s/epoch - 324ms/step
# Epoch 113/150
# 9/9 - 3s - loss: 26.2753 - binary_accuracy: 0.5761 - val_loss: 5.1496 - val_binary_accuracy: 0.7353 - 3s/epoch - 326ms/step
# Epoch 114/150
# 9/9 - 3s - loss: 26.1565 - binary_accuracy: 0.4928 - val_loss: 5.3054 - val_binary_accuracy: 0.7353 - 3s/epoch - 326ms/step
# Epoch 115/150
# 9/9 - 3s - loss: 22.3960 - binary_accuracy: 0.6522 - val_loss: 22.1024 - val_binary_accuracy: 0.5882 - 3s/epoch - 327ms/step
# Epoch 116/150
# 9/9 - 3s - loss: 25.3060 - binary_accuracy: 0.5906 - val_loss: 8.3618 - val_binary_accuracy: 0.6618 - 3s/epoch - 323ms/step
# Epoch 117/150
# 9/9 - 3s - loss: 21.3482 - binary_accuracy: 0.5761 - val_loss: 9.1342 - val_binary_accuracy: 0.6618 - 3s/epoch - 323ms/step
# Epoch 118/150
# 9/9 - 3s - loss: 19.2797 - binary_accuracy: 0.5978 - val_loss: 4.2554 - val_binary_accuracy: 0.7500 - 3s/epoch - 323ms/step
# Epoch 119/150
# 9/9 - 3s - loss: 17.4160 - binary_accuracy: 0.6087 - val_loss: 4.2299 - val_binary_accuracy: 0.7500 - 3s/epoch - 325ms/step
# Epoch 120/150
# 9/9 - 3s - loss: 21.9380 - binary_accuracy: 0.5833 - val_loss: 6.0652 - val_binary_accuracy: 0.6912 - 3s/epoch - 325ms/step
# Epoch 121/150
# 9/9 - 3s - loss: 20.9814 - binary_accuracy: 0.5145 - val_loss: 4.7685 - val_binary_accuracy: 0.7353 - 3s/epoch - 324ms/step
# Epoch 122/150
# 9/9 - 3s - loss: 23.5394 - binary_accuracy: 0.5435 - val_loss: 6.0541 - val_binary_accuracy: 0.6618 - 3s/epoch - 323ms/step
# Epoch 123/150
# 9/9 - 3s - loss: 20.8144 - binary_accuracy: 0.5833 - val_loss: 4.5660 - val_binary_accuracy: 0.7500 - 3s/epoch - 328ms/step
# Epoch 124/150
# 9/9 - 3s - loss: 24.9659 - binary_accuracy: 0.5688 - val_loss: 4.6076 - val_binary_accuracy: 0.7353 - 3s/epoch - 321ms/step
# Epoch 125/150
# 9/9 - 3s - loss: 21.7453 - binary_accuracy: 0.6413 - val_loss: 5.7635 - val_binary_accuracy: 0.6618 - 3s/epoch - 318ms/step
# Epoch 126/150
# 9/9 - 3s - loss: 17.9969 - binary_accuracy: 0.5688 - val_loss: 4.1732 - val_binary_accuracy: 0.7353 - 3s/epoch - 323ms/step
# Epoch 127/150
# 9/9 - 3s - loss: 17.0122 - binary_accuracy: 0.5797 - val_loss: 4.5120 - val_binary_accuracy: 0.7353 - 3s/epoch - 326ms/step
# Epoch 128/150
# 9/9 - 3s - loss: 17.7659 - binary_accuracy: 0.5906 - val_loss: 3.9310 - val_binary_accuracy: 0.7500 - 3s/epoch - 323ms/step
# Epoch 129/150
# 9/9 - 3s - loss: 19.5823 - binary_accuracy: 0.5906 - val_loss: 5.2472 - val_binary_accuracy: 0.7059 - 3s/epoch - 325ms/step
# Epoch 130/150
# 9/9 - 3s - loss: 13.2865 - binary_accuracy: 0.6268 - val_loss: 8.2820 - val_binary_accuracy: 0.6471 - 3s/epoch - 326ms/step
# Epoch 131/150
# 9/9 - 3s - loss: 31.1901 - binary_accuracy: 0.4565 - val_loss: 16.5927 - val_binary_accuracy: 0.5882 - 3s/epoch - 324ms/step
# Epoch 132/150
# 9/9 - 3s - loss: 21.6484 - binary_accuracy: 0.5833 - val_loss: 12.3431 - val_binary_accuracy: 0.6029 - 3s/epoch - 329ms/step
# Epoch 133/150
# 9/9 - 3s - loss: 19.6429 - binary_accuracy: 0.6123 - val_loss: 7.9172 - val_binary_accuracy: 0.6618 - 3s/epoch - 322ms/step
# Epoch 134/150
# 9/9 - 3s - loss: 22.8435 - binary_accuracy: 0.5616 - val_loss: 5.1652 - val_binary_accuracy: 0.7206 - 3s/epoch - 315ms/step
# Epoch 135/150
# 9/9 - 3s - loss: 27.2788 - binary_accuracy: 0.5145 - val_loss: 5.2934 - val_binary_accuracy: 0.6912 - 3s/epoch - 328ms/step
# Epoch 136/150
# 9/9 - 3s - loss: 15.0092 - binary_accuracy: 0.6594 - val_loss: 7.9933 - val_binary_accuracy: 0.6471 - 3s/epoch - 330ms/step
# Epoch 137/150
# 9/9 - 3s - loss: 17.3665 - binary_accuracy: 0.5761 - val_loss: 3.6400 - val_binary_accuracy: 0.7647 - 3s/epoch - 323ms/step
# Epoch 138/150
# 9/9 - 3s - loss: 18.7562 - binary_accuracy: 0.5362 - val_loss: 8.8015 - val_binary_accuracy: 0.6618 - 3s/epoch - 325ms/step
# Epoch 139/150
# 9/9 - 3s - loss: 23.1934 - binary_accuracy: 0.6486 - val_loss: 5.2912 - val_binary_accuracy: 0.6765 - 3s/epoch - 323ms/step
# Epoch 140/150
# 9/9 - 3s - loss: 18.4256 - binary_accuracy: 0.5616 - val_loss: 4.8148 - val_binary_accuracy: 0.7206 - 3s/epoch - 327ms/step
# Epoch 141/150
# 9/9 - 3s - loss: 22.7674 - binary_accuracy: 0.6522 - val_loss: 9.5708 - val_binary_accuracy: 0.6029 - 3s/epoch - 322ms/step
# Epoch 142/150
# 9/9 - 3s - loss: 18.9605 - binary_accuracy: 0.5326 - val_loss: 3.6063 - val_binary_accuracy: 0.7794 - 3s/epoch - 327ms/step
# Epoch 143/150
# 9/9 - 3s - loss: 18.7689 - binary_accuracy: 0.5616 - val_loss: 6.6896 - val_binary_accuracy: 0.6912 - 3s/epoch - 328ms/step
# Epoch 144/150
# 9/9 - 3s - loss: 14.0609 - binary_accuracy: 0.6304 - val_loss: 4.6452 - val_binary_accuracy: 0.7206 - 3s/epoch - 346ms/step
# Epoch 145/150
# 9/9 - 3s - loss: 14.7405 - binary_accuracy: 0.5725 - val_loss: 3.6133 - val_binary_accuracy: 0.7941 - 3s/epoch - 358ms/step
# Epoch 146/150
# 9/9 - 3s - loss: 20.0489 - binary_accuracy: 0.5181 - val_loss: 3.9398 - val_binary_accuracy: 0.7500 - 3s/epoch - 356ms/step
# Epoch 147/150
# 9/9 - 3s - loss: 21.8350 - binary_accuracy: 0.5688 - val_loss: 3.7420 - val_binary_accuracy: 0.7647 - 3s/epoch - 341ms/step
# Epoch 148/150
# 9/9 - 3s - loss: 13.8875 - binary_accuracy: 0.5833 - val_loss: 3.3946 - val_binary_accuracy: 0.7647 - 3s/epoch - 336ms/step
# Epoch 149/150
# 9/9 - 3s - loss: 14.2141 - binary_accuracy: 0.5616 - val_loss: 5.8157 - val_binary_accuracy: 0.7206 - 3s/epoch - 325ms/step
# Epoch 150/150
# 9/9 - 3s - loss: 25.1547 - binary_accuracy: 0.6123 - val_loss: 4.5943 - val_binary_accuracy: 0.7059 - 3s/epoch - 324ms/step

# %%
#accuracy
plt.plot(result.history['binary_accuracy'])
plt.plot(result.history['val_binary_accuracy'])
# plt.plot(result.history['accuracy'])
# plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# OPTIONAL: Decide if best weights should be loaded from previous model based on val_acc
# The model weights (that are considered the best) are loaded into the model.
result = model.load_weights(checkpoint_filepath)

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model
model.save("Models/ResNet50V2/ResNet50V2_covid_classification.h5")

os.chdir(destination)

# %% [markdown]
# <h3>Evaluate Test data</h3>

# %%
print(sum(cb.logs) / 150)

testLoss, testAcc = model.evaluate(test)
print('''
Test Loss: {}
Test Accuracy: {}
'''.format(testLoss, testAcc))
# Out:
# 3.0818773606665975
# 3/3 [==============================] - 2s 716ms/step - loss: 8.1723 - binary_accuracy: 0.6860
#
# Test Loss: 8.172279357910156
# Test Accuracy: 0.6860465407371521

# %% [markdown]
# <h4>*Optional - Fine tune model with two-step training*</h4>

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

mobile.trainable = True

for layer in mobile.layers[:-2]:
    layer.trainable = False
    
#re-train the model at a very low learning rate
model.compile(optimizer=Adam(learning_rate=0.00006), loss='binary_crossentropy', metrics=['binary_accuracy'])

result = model.fit(x=train, validation_data=validation, epochs=100, verbose=2, callbacks=[cb, es])
# Out:
# Epoch 1/100
# 9/9 - 7s - loss: 18.7641 - binary_accuracy: 0.6341 - val_loss: 4.6605 - val_binary_accuracy: 0.7500 - 7s/epoch - 752ms/step
# Epoch 2/100
# 9/9 - 3s - loss: 17.8120 - binary_accuracy: 0.6051 - val_loss: 4.2177 - val_binary_accuracy: 0.7647 - 3s/epoch - 347ms/step
# Epoch 3/100
# 9/9 - 3s - loss: 16.1859 - binary_accuracy: 0.6377 - val_loss: 4.2116 - val_binary_accuracy: 0.7647 - 3s/epoch - 337ms/step
# Epoch 4/100
# 9/9 - 3s - loss: 22.3246 - binary_accuracy: 0.5725 - val_loss: 4.3938 - val_binary_accuracy: 0.7500 - 3s/epoch - 335ms/step
# Epoch 5/100
# 9/9 - 3s - loss: 14.8066 - binary_accuracy: 0.6196 - val_loss: 4.3697 - val_binary_accuracy: 0.7500 - 3s/epoch - 334ms/step
# Epoch 6/100
# 9/9 - 3s - loss: 14.9344 - binary_accuracy: 0.6196 - val_loss: 4.2923 - val_binary_accuracy: 0.7794 - 3s/epoch - 338ms/step
# Epoch 7/100
# 9/9 - 3s - loss: 17.1872 - binary_accuracy: 0.6159 - val_loss: 4.4053 - val_binary_accuracy: 0.7500 - 3s/epoch - 354ms/step
# Epoch 8/100
# 9/9 - 3s - loss: 17.1025 - binary_accuracy: 0.5978 - val_loss: 4.3533 - val_binary_accuracy: 0.7500 - 3s/epoch - 338ms/step
# Epoch 9/100
# 9/9 - 3s - loss: 15.9621 - binary_accuracy: 0.5797 - val_loss: 4.2138 - val_binary_accuracy: 0.7500 - 3s/epoch - 336ms/step
# Epoch 10/100
# 9/9 - 3s - loss: 18.4729 - binary_accuracy: 0.6159 - val_loss: 4.2215 - val_binary_accuracy: 0.7794 - 3s/epoch - 332ms/step
# Epoch 11/100
# 9/9 - 3s - loss: 15.6218 - binary_accuracy: 0.6232 - val_loss: 4.3260 - val_binary_accuracy: 0.7500 - 3s/epoch - 337ms/step
# Epoch 12/100
# 9/9 - 3s - loss: 21.2716 - binary_accuracy: 0.5833 - val_loss: 4.6358 - val_binary_accuracy: 0.7500 - 3s/epoch - 328ms/step
# Epoch 13/100
# 9/9 - 3s - loss: 17.0939 - binary_accuracy: 0.6196 - val_loss: 4.4112 - val_binary_accuracy: 0.7500 - 3s/epoch - 335ms/step
# Epoch 13: early stopping

# %% [markdown]
# <h3>Accuracy and Loss graph</h3>

# %%
#accuracy
plt.plot(result.history['binary_accuracy'])
plt.plot(result.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# <h3>Classification report</h3>

# %%
predictions = model.predict(test, verbose=0)
# predictions = predictions.reshape(1,-1)[0]
# lst = np.argmax(predictions, axis= 1)
lst = (predictions > 0.5).astype(int)

print(classification_report(test.classes, lst, target_names = test.class_indices))
# Out:
#               precision    recall  f1-score   support
#
#        covid       0.60      0.50      0.55        36
#       normal       0.68      0.76      0.72        50
#
#     accuracy                           0.65        86
#    macro avg       0.64      0.63      0.63        86
# weighted avg       0.65      0.65      0.65        86

# %% [markdown]
# <h3>Confusion matrix</h3>

# %%
result = confusion_matrix(test.classes, lst)
print(result)

def plot_confusion_matrix(result, classes, cmap=plt.cm.Blues):
    plt.subplots(figsize=(7, 7))
    plt.imshow(result, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

    thresh = result.max() / 2.
    for i, j in itertools.product(range(result.shape[0]), range(result.shape[1])):
        plt.text(j, i, result[i, j],
            horizontalalignment="center",
            color = "white" if result[i, j] > thresh else "black")
        
    #current matplotlib version will cut off top and bottom of the matrix, 
    #hence the manual workaround - remove if matplotlib version does not cut off
    b, t = plt.ylim() # discover bottom and top values
    b += 0.5 # Add 0.5 to bottom
    t -= 0.5 # Subtract 0.5 from top
    plt.ylim(b, t) # update ylim(bottom, top) values
    plt.show()
    
plot_confusion_matrix(result, list(test.class_indices.keys()))
# Out:
# [[18 18]
#  [12 38]]

# %% [markdown]
# <h3>Save the model</h3>

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model
model.save("Models/ResNet50V2/ResNet50V2_covid_classification_finetuned.h5")
