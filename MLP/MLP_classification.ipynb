# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import tensorflow as tf

covid_dir = "C:/Users/Cheeyee/3009/CovidClassification/dataset_6/covid"
normal_dir = "C:/Users/Cheeyee/3009/CovidClassification/dataset_6/normal"

# Load images and labels
def load_data_from_directory(directory, label):
    images = []
    labels = []
    for filename in os.listdir(directory):
        if filename.endswith(".png"):
            img_path = os.path.join(directory, filename)
            img = cv2.imread(img_path)
            img = cv2.resize(img, (299, 299))
            images.append(img)
            labels.append(label)
    return images, labels

# Load COVID images and labels
covid_images, covid_labels = load_data_from_directory(covid_dir, "covid")

# Load normal images and labels
normal_images, normal_labels = load_data_from_directory(normal_dir, "normal")

# Combine the data and labels for COVID and normal images
X_data = np.array(covid_images + normal_images)
y_data = np.array(covid_labels + normal_labels)

# Convert labels to one-hot encoded vectors
label_encoder = LabelEncoder()
y_data = label_encoder.fit_transform(y_data)
y_data = tf.keras.utils.to_categorical(y_data)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=42)

# Flatten for MLP
input_shape = X_train.shape[1] * X_train.shape[2] * X_train.shape[3]
X_train_flat = X_train.reshape(X_train.shape[0], input_shape)
X_test_flat = X_test.reshape(X_test.shape[0], input_shape)

# Normalize pixel to [0, 1]
X_train_flat = X_train_flat / 255.0
X_test_flat = X_test_flat / 255.0

# Create Multi-Layer Perceptron (MLP) model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(512, activation='relu', input_shape=(input_shape,)),
    tf.keras.layers.BatchNormalization(),  # Add BatchNormalization layer
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),  # Add BatchNormalization layer
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(2, activation='softmax')
])

# Learning rate scheduler
initial_learning_rate = 0.0001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=1000,
    decay_rate=0.96,
    staircase=True
)

# Compile the model with the new learning rate
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adamax(learning_rate=lr_schedule), metrics=['accuracy'])

# Train the model
history = model.fit(X_train_flat, y_train, batch_size=32, epochs=125, validation_data=(X_test_flat, y_test))

# Plotting accuracy and loss over epochs
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
y_pred = model.predict(X_test_flat)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

print("Classification Report:")
print(classification_report(y_true_labels, y_pred_labels, target_names=label_encoder.classes_))

# Display the confusion matrix
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(6, 6))
plt.imshow(conf_matrix, cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
class_names = label_encoder.classes_
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=45)
plt.yticks(tick_marks, class_names)
plt.colorbar()

for i in range(len(class_names)):
    for j in range(len(class_names)):
        plt.text(j, i, str(conf_matrix[i, j]), ha='center', va='center')

plt.show()
# Out:
# Epoch 1/125
# 11/11 [==============================] - 14s 1s/step - loss: 1.1742 - accuracy: 0.5378 - val_loss: 7.5160 - val_accuracy: 0.4884
# Epoch 2/125
# 11/11 [==============================] - 12s 1s/step - loss: 1.0769 - accuracy: 0.5988 - val_loss: 4.3220 - val_accuracy: 0.4884
# Epoch 3/125
# 11/11 [==============================] - 12s 1s/step - loss: 1.0677 - accuracy: 0.5814 - val_loss: 2.4717 - val_accuracy: 0.4884
# Epoch 4/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.9782 - accuracy: 0.6250 - val_loss: 1.8158 - val_accuracy: 0.4884
# Epoch 5/125
# 11/11 [==============================] - 12s 1s/step - loss: 1.0063 - accuracy: 0.6395 - val_loss: 1.2209 - val_accuracy: 0.5233
# Epoch 6/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.8295 - accuracy: 0.7151 - val_loss: 0.9248 - val_accuracy: 0.5930
# Epoch 7/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.8560 - accuracy: 0.7064 - val_loss: 0.6011 - val_accuracy: 0.7093
# Epoch 8/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7731 - accuracy: 0.6773 - val_loss: 0.5420 - val_accuracy: 0.7791
# Epoch 9/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.9020 - accuracy: 0.6773 - val_loss: 0.5646 - val_accuracy: 0.7907
# Epoch 10/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.9309 - accuracy: 0.6715 - val_loss: 0.5461 - val_accuracy: 0.7674
# Epoch 11/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.8091 - accuracy: 0.6831 - val_loss: 0.5188 - val_accuracy: 0.7907
# Epoch 12/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.8157 - accuracy: 0.6890 - val_loss: 0.5263 - val_accuracy: 0.7791
# Epoch 13/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.8377 - accuracy: 0.6483 - val_loss: 0.5593 - val_accuracy: 0.7674
# Epoch 14/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6911 - accuracy: 0.7151 - val_loss: 0.5019 - val_accuracy: 0.8140
# Epoch 15/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7994 - accuracy: 0.7209 - val_loss: 0.5439 - val_accuracy: 0.8023
# Epoch 16/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7596 - accuracy: 0.6977 - val_loss: 0.4866 - val_accuracy: 0.8023
# Epoch 17/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7301 - accuracy: 0.7238 - val_loss: 0.4358 - val_accuracy: 0.8140
# Epoch 18/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7800 - accuracy: 0.7500 - val_loss: 0.4036 - val_accuracy: 0.8256
# Epoch 19/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7536 - accuracy: 0.7093 - val_loss: 0.3931 - val_accuracy: 0.7907
# Epoch 20/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7047 - accuracy: 0.7093 - val_loss: 0.4172 - val_accuracy: 0.7907
# Epoch 21/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7866 - accuracy: 0.7326 - val_loss: 0.4485 - val_accuracy: 0.8140
# Epoch 22/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7170 - accuracy: 0.7297 - val_loss: 0.3950 - val_accuracy: 0.7791
# Epoch 23/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6461 - accuracy: 0.7674 - val_loss: 0.3762 - val_accuracy: 0.8140
# Epoch 24/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7250 - accuracy: 0.7355 - val_loss: 0.3916 - val_accuracy: 0.7674
# Epoch 25/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6767 - accuracy: 0.7093 - val_loss: 0.4612 - val_accuracy: 0.7558
# Epoch 26/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7188 - accuracy: 0.7326 - val_loss: 0.4795 - val_accuracy: 0.7558
# Epoch 27/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5899 - accuracy: 0.7616 - val_loss: 0.4309 - val_accuracy: 0.7558
# Epoch 28/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.8235 - accuracy: 0.6948 - val_loss: 0.4429 - val_accuracy: 0.7558
# Epoch 29/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6341 - accuracy: 0.7500 - val_loss: 0.4441 - val_accuracy: 0.7558
# Epoch 30/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7511 - accuracy: 0.7413 - val_loss: 0.5354 - val_accuracy: 0.7674
# Epoch 31/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6545 - accuracy: 0.7297 - val_loss: 0.4506 - val_accuracy: 0.7674
# Epoch 32/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6466 - accuracy: 0.7849 - val_loss: 0.5017 - val_accuracy: 0.7674
# Epoch 33/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5673 - accuracy: 0.7733 - val_loss: 0.5341 - val_accuracy: 0.7558
# Epoch 34/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7135 - accuracy: 0.7064 - val_loss: 0.5711 - val_accuracy: 0.7674
# Epoch 35/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6048 - accuracy: 0.7733 - val_loss: 0.6846 - val_accuracy: 0.7326
# Epoch 36/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6689 - accuracy: 0.7209 - val_loss: 0.5923 - val_accuracy: 0.7558
# Epoch 37/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6968 - accuracy: 0.7442 - val_loss: 0.4217 - val_accuracy: 0.7674
# Epoch 38/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7075 - accuracy: 0.7413 - val_loss: 0.3828 - val_accuracy: 0.8140
# Epoch 39/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.7053 - accuracy: 0.7733 - val_loss: 0.3918 - val_accuracy: 0.8023
# Epoch 40/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5978 - accuracy: 0.7471 - val_loss: 0.3962 - val_accuracy: 0.7791
# Epoch 41/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6178 - accuracy: 0.7529 - val_loss: 0.4020 - val_accuracy: 0.7674
# Epoch 42/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6928 - accuracy: 0.7267 - val_loss: 0.4257 - val_accuracy: 0.7907
# Epoch 43/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6462 - accuracy: 0.7558 - val_loss: 0.4855 - val_accuracy: 0.7907
# Epoch 44/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5324 - accuracy: 0.7674 - val_loss: 0.5175 - val_accuracy: 0.7791
# Epoch 45/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5217 - accuracy: 0.8140 - val_loss: 0.4946 - val_accuracy: 0.7674
# Epoch 46/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5123 - accuracy: 0.8110 - val_loss: 0.4363 - val_accuracy: 0.7791
# Epoch 47/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5674 - accuracy: 0.7529 - val_loss: 0.3590 - val_accuracy: 0.7791
# Epoch 48/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6428 - accuracy: 0.7645 - val_loss: 0.3743 - val_accuracy: 0.7674
# Epoch 49/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6090 - accuracy: 0.7558 - val_loss: 0.4630 - val_accuracy: 0.7674
# Epoch 50/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6199 - accuracy: 0.7529 - val_loss: 0.5166 - val_accuracy: 0.7558
# Epoch 51/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6122 - accuracy: 0.7733 - val_loss: 0.4064 - val_accuracy: 0.7674
# Epoch 52/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6059 - accuracy: 0.7529 - val_loss: 0.3924 - val_accuracy: 0.8256
# Epoch 53/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5030 - accuracy: 0.7936 - val_loss: 0.5223 - val_accuracy: 0.7791
# Epoch 54/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5825 - accuracy: 0.7762 - val_loss: 0.5561 - val_accuracy: 0.7674
# Epoch 55/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5378 - accuracy: 0.8081 - val_loss: 0.4358 - val_accuracy: 0.7907
# Epoch 56/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5686 - accuracy: 0.7907 - val_loss: 0.3587 - val_accuracy: 0.7674
# Epoch 57/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6032 - accuracy: 0.7936 - val_loss: 0.4357 - val_accuracy: 0.7791
# Epoch 58/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5771 - accuracy: 0.7849 - val_loss: 0.4555 - val_accuracy: 0.8023
# Epoch 59/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5942 - accuracy: 0.7645 - val_loss: 0.4529 - val_accuracy: 0.7907
# Epoch 60/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5053 - accuracy: 0.7674 - val_loss: 0.5272 - val_accuracy: 0.7907
# Epoch 61/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5757 - accuracy: 0.8052 - val_loss: 0.4183 - val_accuracy: 0.7558
# Epoch 62/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4936 - accuracy: 0.7936 - val_loss: 0.3573 - val_accuracy: 0.8372
# Epoch 63/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4786 - accuracy: 0.7878 - val_loss: 0.3398 - val_accuracy: 0.8488
# Epoch 64/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5723 - accuracy: 0.7878 - val_loss: 0.3392 - val_accuracy: 0.8488
# Epoch 65/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6619 - accuracy: 0.7442 - val_loss: 0.3368 - val_accuracy: 0.7674
# Epoch 66/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6219 - accuracy: 0.7645 - val_loss: 0.3422 - val_accuracy: 0.7674
# Epoch 67/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5919 - accuracy: 0.7907 - val_loss: 0.3757 - val_accuracy: 0.8256
# Epoch 68/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5221 - accuracy: 0.7878 - val_loss: 0.3831 - val_accuracy: 0.8140
# Epoch 69/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5142 - accuracy: 0.7791 - val_loss: 0.3383 - val_accuracy: 0.8023
# Epoch 70/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6198 - accuracy: 0.7703 - val_loss: 0.3848 - val_accuracy: 0.7907
# Epoch 71/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6531 - accuracy: 0.7500 - val_loss: 0.4714 - val_accuracy: 0.7791
# Epoch 72/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4679 - accuracy: 0.7994 - val_loss: 0.3997 - val_accuracy: 0.7907
# Epoch 73/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6298 - accuracy: 0.7587 - val_loss: 0.4062 - val_accuracy: 0.8023
# Epoch 74/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4900 - accuracy: 0.7703 - val_loss: 0.3809 - val_accuracy: 0.8256
# Epoch 75/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5069 - accuracy: 0.7820 - val_loss: 0.3557 - val_accuracy: 0.8023
# Epoch 76/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4483 - accuracy: 0.8285 - val_loss: 0.4717 - val_accuracy: 0.7442
# Epoch 77/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5055 - accuracy: 0.8023 - val_loss: 0.4393 - val_accuracy: 0.7326
# Epoch 78/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5844 - accuracy: 0.7645 - val_loss: 0.3584 - val_accuracy: 0.7674
# Epoch 79/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5869 - accuracy: 0.7849 - val_loss: 0.3401 - val_accuracy: 0.8256
# Epoch 80/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5093 - accuracy: 0.7849 - val_loss: 0.3353 - val_accuracy: 0.8953
# Epoch 81/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5681 - accuracy: 0.7703 - val_loss: 0.3386 - val_accuracy: 0.8488
# Epoch 82/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5601 - accuracy: 0.7878 - val_loss: 0.3354 - val_accuracy: 0.8488
# Epoch 83/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5297 - accuracy: 0.7849 - val_loss: 0.3503 - val_accuracy: 0.8372
# Epoch 84/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5584 - accuracy: 0.8052 - val_loss: 0.3692 - val_accuracy: 0.8372
# Epoch 85/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5171 - accuracy: 0.7878 - val_loss: 0.4242 - val_accuracy: 0.8023
# Epoch 86/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5417 - accuracy: 0.7994 - val_loss: 0.4355 - val_accuracy: 0.8140
# Epoch 87/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4485 - accuracy: 0.8140 - val_loss: 0.4330 - val_accuracy: 0.8256
# Epoch 88/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5765 - accuracy: 0.7965 - val_loss: 0.4304 - val_accuracy: 0.8140
# Epoch 89/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5109 - accuracy: 0.7849 - val_loss: 0.4125 - val_accuracy: 0.8140
# Epoch 90/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6467 - accuracy: 0.7878 - val_loss: 0.4460 - val_accuracy: 0.7674
# Epoch 91/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4823 - accuracy: 0.8110 - val_loss: 0.4380 - val_accuracy: 0.8023
# Epoch 92/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5856 - accuracy: 0.7674 - val_loss: 0.4054 - val_accuracy: 0.7791
# Epoch 93/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5487 - accuracy: 0.7674 - val_loss: 0.4636 - val_accuracy: 0.7558
# Epoch 94/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4544 - accuracy: 0.8023 - val_loss: 0.4065 - val_accuracy: 0.8023
# Epoch 95/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5376 - accuracy: 0.7936 - val_loss: 0.4620 - val_accuracy: 0.7558
# Epoch 96/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4528 - accuracy: 0.8169 - val_loss: 0.4496 - val_accuracy: 0.7791
# Epoch 97/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4611 - accuracy: 0.8198 - val_loss: 0.4186 - val_accuracy: 0.7791
# Epoch 98/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4311 - accuracy: 0.8052 - val_loss: 0.4959 - val_accuracy: 0.7558
# Epoch 99/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.6062 - accuracy: 0.7733 - val_loss: 0.5354 - val_accuracy: 0.7326
# Epoch 100/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4553 - accuracy: 0.8343 - val_loss: 0.4314 - val_accuracy: 0.7558
# Epoch 101/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5089 - accuracy: 0.7762 - val_loss: 0.4675 - val_accuracy: 0.7558
# Epoch 102/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4480 - accuracy: 0.8169 - val_loss: 0.4607 - val_accuracy: 0.7442
# Epoch 103/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5272 - accuracy: 0.7762 - val_loss: 0.4717 - val_accuracy: 0.7558
# Epoch 104/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5063 - accuracy: 0.8023 - val_loss: 0.4804 - val_accuracy: 0.7558
# Epoch 105/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5490 - accuracy: 0.7587 - val_loss: 0.5623 - val_accuracy: 0.7674
# Epoch 106/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5012 - accuracy: 0.7762 - val_loss: 0.5910 - val_accuracy: 0.7209
# Epoch 107/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4565 - accuracy: 0.8110 - val_loss: 0.4859 - val_accuracy: 0.7558
# Epoch 108/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5179 - accuracy: 0.7820 - val_loss: 0.4606 - val_accuracy: 0.7907
# Epoch 109/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4673 - accuracy: 0.7965 - val_loss: 0.4801 - val_accuracy: 0.7674
# Epoch 110/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5577 - accuracy: 0.8023 - val_loss: 0.4219 - val_accuracy: 0.7791
# Epoch 111/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4242 - accuracy: 0.8314 - val_loss: 0.3591 - val_accuracy: 0.8140
# Epoch 112/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4581 - accuracy: 0.8110 - val_loss: 0.3611 - val_accuracy: 0.8256
# Epoch 113/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4241 - accuracy: 0.8227 - val_loss: 0.4524 - val_accuracy: 0.8023
# Epoch 114/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5863 - accuracy: 0.7762 - val_loss: 0.3454 - val_accuracy: 0.8605
# Epoch 115/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4611 - accuracy: 0.8023 - val_loss: 0.3589 - val_accuracy: 0.8256
# Epoch 116/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4692 - accuracy: 0.8110 - val_loss: 0.4264 - val_accuracy: 0.7907
# Epoch 117/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4791 - accuracy: 0.7994 - val_loss: 0.5242 - val_accuracy: 0.7558
# Epoch 118/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5059 - accuracy: 0.8023 - val_loss: 0.6248 - val_accuracy: 0.7209
# Epoch 119/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5275 - accuracy: 0.7907 - val_loss: 0.4616 - val_accuracy: 0.7907
# Epoch 120/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5376 - accuracy: 0.7965 - val_loss: 0.3778 - val_accuracy: 0.8256
# Epoch 121/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.5693 - accuracy: 0.7965 - val_loss: 0.3811 - val_accuracy: 0.7791
# Epoch 122/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4392 - accuracy: 0.8081 - val_loss: 0.3693 - val_accuracy: 0.7558
# Epoch 123/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4480 - accuracy: 0.8227 - val_loss: 0.3407 - val_accuracy: 0.8488
# Epoch 124/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4803 - accuracy: 0.8140 - val_loss: 0.3467 - val_accuracy: 0.8605
# Epoch 125/125
# 11/11 [==============================] - 12s 1s/step - loss: 0.4708 - accuracy: 0.8023 - val_loss: 0.3473 - val_accuracy: 0.8023
# 3/3 [==============================] - 0s 47ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        covid       0.85      0.75      0.80        44
#       normal       0.77      0.86      0.81        42
#
#     accuracy                           0.80        86
#    macro avg       0.81      0.80      0.80        86
# weighted avg       0.81      0.80      0.80        86
